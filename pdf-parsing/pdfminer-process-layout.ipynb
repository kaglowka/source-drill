# %%
import numpy as np
import re
import matplotlib
from matplotlib import pyplot as plt
import sys
import os

# %matplotlib inline

# %%
# pdfs to work on
sample_pdf_dir = '../sample_pdfs'
sample_pdfs = [file for file in os.listdir(sample_pdf_dir) if file.split('.')[-1] == 'pdf']
output_dir = 'output'

# %%
# Shitty experiments with pdftotext
import pdftotext


# Load your PDF
with open(os.path.join(sample_pdf_dir, '2019.pdf'), "rb") as f:
    pdf = pdftotext.PDF(f)

# How many pages?
# print(len(pdf))

# Iterate over all the pages
for i, page in enumerate(pdf):
#     page = re.sub(page, r'\n+', r'\n')
    page = re.sub(r'[ \t]+', ' ', page)
    print('\n\n\n\n\n\nPAGE {}'.format(i + 1), page, '\n')

# Read some individual pages
# print(pdf[0])
# print(pdf[1])

# Read all the text into one string
# print("\n\n".join(pdf)

# print("\n\n".join(pdf))
# Out:
# PAGE 1  Extending Machine Language Models toward
#  Human-Level Language Understanding
#  James L. McClellanda,b,2 , Felix Hillb,2 , Maja Rudolphc,2 , Jason Baldridged,1,2 , and Hinrich Schützee,1,2
#  a
#  Stanford University, Stanford, CA 94305, USA; b DeepMind, London N1C 4AG, UK; c Bosch Center for Artificial Intelligence, Renningen, 71272, Germany; d Google Research,
#  Austin, TX 78701, USA; e LMU Munich, Munich, 80538, Germany
#  This manuscript was compiled on December 13, 2019
#  Language is central to human intelligence. We review recent break- phenomenon, captured in learned connection weights and re-
#  throughs in machine language processing and consider what re- sulting in context-sensitive, distributed representations whose
#  mains to be achieved. Recent approaches rely on domain general characteristics reflect a gradual, input-statistics dependent,
#  principles of learning and representation captured in artificial neu- learning process (4). The models treat the symbols and rules
# arXiv:1912.05877v1 [cs.CL] 12 Dec 2019
#  ral networks. Most current models, however, focus too closely on of classical linguistic theory as consequences of processing and
#  language itself. In humans, language is part of a larger system for learning, not entities whose structure must be built in. Instead
#  acquiring, representing, and communicating about objects and sit- of discrete symbols for linguistic units, these models rely on
#  uations in the physical and social world, and future machine lan- patterns of activity often called embeddings over arrays of
#  guage models should emulate such a system. We describe exist- neuron-like processing units. Instead of explicit systems of
#  ing machine models linking language to concrete situations, and rules, they rely on learned matrices of connection weights to
#  point toward extensions to address more abstract cases. Human map patterns on one set of units into patterns on others.
#  language processing exploits complementary learning systems, in- Another key principle is mutual constraint satisfaction (5).
#  cluding a deep neural network-like learning system that learns grad- For example, the meaning of a sentence depends on its struc-
#  ually as machine systems do, as well as a fast-learning system that ture (its organization into constituent phrases); but so too can
#  supports learning new information quickly. Adding such a system to the structure depend on the meaning. Consider the sentence A
#  machine language models will be an important further step toward boy hit a man with a __. If the missing word is bat, with a bat
#  truly human-like language understanding. is read as part of a verb phrase headed by hit, and specifies the
#  instrument used to carry out the action. But if beard fills the
#  Language Understanding | Natural Language Processing | Situation
#  blank, with a beard is a part of a noun phrase describing who
#  Models | Machine Language Models | Brain System for Understanding
#  was hit. Even the segmentation of spoken or written language
#  into elementary segments (e.g., letters) depends in part on
#  Many of the most impressive recent successes of machine in-
#  meaning and context, as illustrated in Fig. 1. Rumelhart (5)
#  telligence have appeared in the domain of language. Machines
#  sketched an interactive model of language understanding in
#  can now better identify the words we speak and respond in
#  which estimates of probabilities about all aspects of an input
#  ever more natural sounding voices. More impressive still is
#  constrain estimates of the probability of every other aspect.
#  modern machine translation (1). Anyone with a smartphone
#  The idea was captured in a model of context effects in per-
#  has access to applications that allow them to say a sentence in
#  ception (6). Later work (7, 8) linked these ideas to energy
#  one language and then see and hear its translation in another.
#  minimization in statistical physics. Neural language modeling
#  Human ability still far exceeds machines in most language
#  research, which we now describe, incorporates these principles.
#  tasks, but these systems work well enough to be used by
#  billions of people everyday.
#  What underlies these successes, and what limitations do Neural Language Modeling
#  these systems face? We argue that successes to date come from An Early Neural Language Model. Elman (9) built on the prin-
#  ever more effective methods for exploiting principles of neural ciples above to demonstrate how neural models can capture
#  computation that human language users also exploit. We then key characteristics of language structure through learning, a
#  note that the work remains limited in that it largely treats feat once considered impossible (10). The model provides a
#  language separately from the larger task of understanding starting point for understanding recent developments. Elman
#  the world around us. This leads us to propose an integrated used the recurrent neural network shown in Fig. 2a. The
#  approach to building a system that truly understands, in which network was trained to predict the next word in a sequence
#  language plays a key role in concert with other sources of input. (w(t + 1)) based on the current word (w(t)) and its own hidden
#  We discuss the challenges facing further development of the (that is, learned internal) representation from the previous
#  approach and propose future steps toward addressing these time step (h(t − 1)). These two inputs are each multiplied
#  challenges. by a matrix of connection weights (represented by the arrows
#  labeled Whi and Whh ) to produce vectors that are added to
#  Principles of Neural Computation produce a vector of inputs to the hidden layer of units. The
#  The principles of neural computation are domain general prin-
#  ciples inspired by the human brain. They were first articulated JM, FH, MR, JB, and HS wrote the paper.
#  in the 1950s (2) and further developed in the 1980s in the The authors declare no conflict of interest.
#  Parallel Distributed Processing (PDP) framework for modeling 1
#  J.B. and H.S. contributed equally.
#  cognition (3). A central idea of this approach is that struc- 2
#  To whom correspondence should be addressed. E-mail: jlmccstanford.edu, felixhill@google.com,
#  ture in language and other cognitive domains is an emergent marirudolph@gmail.com, jasonbaldridge@google.com or inquiries@cislmu.org
#  1
#
#
#
#
#
#
#
#
# PAGE 2 Fig. 1. Two handwritten sentences illustrating how context influences the identification
# of letters in written text. The visual input we read as went in the first sentence and
# event in the second is the same bit of Rumelhart’s handwriting, cut and pasted into
# each of the two contexts. Reprinted from (5).
# elements of this vector undergo a transformation limiting the
#  Fig. 2. (a) Elman’s (1990) simple recurrent network and (b) his hierarchical clustering
# range of activation values, resulting in the hidden layer repre-
#  of the representations it learned, reprinted from (9).
# sentation. This in turn is multiplied with the matrix of weights
# to the output layer from the hidden layer (Woh ) to generate a
# vector used to predict the probability of each of the possible the context that might be relevant. Consider this passage:
# successor words. Learning in this and other neural models is
# based on the discrepancy between the network’s output and John put some beer in a cooler and went out with his
# the actual next word; the values of the connection weights friends to play volleyball. Soon after he left, someone
# are adjusted by a small amount to reduce the discrepancy. took the beer out of the cooler. John and his friends
# The network is called recurrent because the same connection were thirsty after the game, and went back to his
# weights (denoted by arrows in the figure) are used to process place for some beers. When John opened the cooler,
# each successive word; the hidden representation h(t) becomes he discovered that the beer was ___.
# the context representation h(t − 1) for the next time step.
#  Elman demonstrated two crucial findings. First, after train- Here a reader expects the missing word to be gone. Yet if
# ing his network to predict the next word in simple sentences like we replaced someone took the beer with someone took the ice
# man eats bread, dog chases cat, and girl sleeps, the network’s the expected word would be warm instead. Furthermore, any
# representations captured the syntactic distinction between amount of additional text between beer and gone would not
# nouns and verbs (9). It also captured interpretable subcate- change the predictive relationship. Elman’s network could
# gories, as shown by a hierarchical clustering of the hidden-layer take only a few words of context into account, reflecting a
# pattern (h(t)) for each word in the training materials (Fig. 2b). larger challenge known as the vanishing gradient problem (12).
# This illustrates a key feature of learned representations in neu- In essence, the magnitude of the learning signal that deter-
# ral models: they capture specific as well as general or abstract mines the adjustments to connection weights tends to decrease
# information. By using a different learned representation for exponentially as the number of layers of weights between an
# each word, the specific predictive consequences of that word input and an output increases. The development of neural
# can be exploited. Because representations for words that make network modules called Long-Short-Term-Memory (LSTM)
# similar predictions are similar, and because neural networks modules (13) that partially overcame this limitation was there-
# exploit similarity, the network can share knowledge about fore crucial, greatly increasing the contextual range of neural
# predictions among related words. Second, Elman (11) used models. In another crucial development, researchers began
# both simple sentences like boy chases dogs and more complex to use pre-trained word embeddings derived from learning
# ones like boy who sees girls chases dogs. In the more complex predictive relationships among words (14, 15). When training
# case, the verb chases must agree with the first noun (boy), not a neural model for a specific task, such embeddings could then
# the closest noun (girls), since the sentence contains a main be used to directly represent training words in the model’s
# clause (boy chases dogs) interrupted by an embedded clause input. The embeddings were based on the aggregate statistics
# (boy [who] sees girls). The model learned to predict the verb of large text corpora, and captured both general and specific
# form correctly despite the intervening clause, showing that it predictive relationships, supporting generalization at both gen-
# acquired sensitivity to the syntactic structure of language, and eral and specific levels. Using these embeddings, task-focused
# not just local co-occurrence statistics in its learned connections models trained with relatively small data sets could generalize
# and distributed representations. what they learned from training on frequent words (such as
#  sofa) to infrequent words with similar predictive relationships
# Scaling Up to Process Natural Text. Elman’s task—predicting
#  (such as settee).
# the next word in a sequence—has been central to neural lan-
# guage modeling. However, Elman trained his networks with A limitation of the above approach is that the same rep-
# only tiny fragments of what were effectively toy languages. resentation of a word is used every time it occurs, regardless
# For many years, it seemed they would not scale up. Beginning of context. However, in line with the principle of mutual
# about 10 years ago, advances in machine language process- constraint satisfaction, humans interpret words, including am-
# ing began to overcome this limitation for neural models. We biguous words like bank, in accordance with the context (16),
# describe two crucial developments next. rapidly assigning a contextually appropriate meaning to each
#  word based on all other words. A fixed embedding also limits
# Long-distance dependencies and pretrained word embeddings. A predicting other words; the predictive implication of the word
# challenge for language prediction is the indefinite length of bank depends on which kind of bank is involved. Initial steps
# McClelland et al.: Language understanding in humans and machines 2
#
#
#
#
#
#
#
#
# PAGE 3  for every intervening word, the context reaches the target
#  directly. Likewise, gradient learning signals skip over the inter-
#  vening words, avoiding the dissipation of learning signal that
#  would otherwise occur.
#  BERT-based models have produced remarkable improve-
#  ments on a wide range of language tasks (25, 26). The models
#  can be pre-trained on massive text corpora, providing useful
#  representations for subsequent tasks for which little specific
#  training data exists (27). These models seem to capture syn-
#  tactic, semantic and world knowledge and they are beginning
# Fig. 3. High-level depiction of one stage of the bidirectional attention architecture,
#  to address tasks once thought beyond their reach. For ex-
# shown constructing a contextually appropriate representation of bank based on other ample, Winograd Schema challenge (28) requires determining
# words in the same sentence. Diagonal lines show how inputs from other positions the referent of a pronoun (here it) in a sentence such as The
# reach bank ’s position; the same occurs at all word positions. See text for details. trophy did not fit in the suitcase because it was too ___. For a
#  person, world knowledge tells us that if the missing word is big
#  the referent must be the trophy, but if it is small the referent
# toward context sensitivity (17) recognize this limitation. We must be the suitcase. The latest models achieve ever-higher
# consider a fuller solution in the next section. scores on benchmarks including variants of the Winograd chal-
#  lenge (29). However, variants of test materials that do not
# Attention and fully contextualized embeddings. Breakthroughs in fool humans continue to stymie even the best models (30), and
# neural language modeling have come from recent models that further refinements in the models and their assessment will be
# construct fully contextualized word representations (18–22). required before it will be clear what such models can achieve.
# The models represent words via a mutual constraint satis-
# faction process in which each word in a text span influences The Human Integrated Understanding System (IUS)
# the representation of every other word. BERT (20) is a key
# model in this class, illustrated in Fig. 3 as it encodes the end Situations and objects. Despite the successes of neural lan-
# of the sentence John reached the bank of the river (example guage modeling, an important limitation is that these models
# from (23)). An initial context-independent representation of are purely language based. We need models in which lan-
# each word is first combined with a positional representation guage is a part of an integrated understanding system (IUS)
# (bottom row of boxes in the figure). Then, a separate copy of for understanding and communicating about the situations
# the same neural network module updates the representation in we encounter and the objects that participate in them. Rep-
# each position with input from all other positions. This process resentations of situations constitute our models of our world
# uses queries (red) at each position that are compared to keys and guide our behavior and our interpretation of language.
# (yellow) at all positions to form weightings (mauve boxes) that Indeed, resolving the referent of the pronoun in a Winograd
# determine how strongly the values (blue) from each position sentence would follow from building a representation of the
# contribute to the combined attention vectors (grey boxes) that situation the sentence describes. In the situation in which a
# provide context-sensitivity. The computation iterates over trombone does not fit in a suitcase, the natural reason would
# many layers, allowing words whose representations have been be that the trombone is too big or the suitcase too small; the
# influenced by their context to influence the representations of identity of the referent of the pronoun follows from realizing
# other words. The process allows selection among alternative this. Thus, solving the Winograd Schema challenge is a natu-
# distinct meanings of a word like bank as well as graded shading ral byproduct of the human language understanding process.
# of word meaning by context, for example assigning different In short, we argue that language evolved for communication
# emotional valance to the dogs in the dog wagged its tail and about situations and our systems should address this goal.
# the dog snarled. Situations can be concrete and static, such as one where
#  a cat is on a mat, or they may be events such as one where
#  Key ingredients of the contemporary models are (i) bidi-
#  a boy hits a ball. They can be conceptual, social or legal,
# rectionality of information flow during processing and (ii) an
#  such as one where a court invalidates a law. They may even
# attention mechanism, which replaces the LSTM mechanism to
#  be imaginary. The objects may be real or fictitious physical
# enhance the exploitation of context. Bidirectionality matters
#  objects or locations; animals, persons, groups or organizations;
# because the meaning of a word in context depends on what
#  beliefs or other states of mind; or entities such as theories,
# comes after it as well as what comes before; in the example
#  laws or constitutions. Here we focus on concrete situations,
# sentence, the last word, river, determines the meaning of bank.
#  considering other cases below. Our proposal builds on classic
# While it is remarkable how much can be done with strictly left-
#  work in linguistics (31, 32), human cognition (33), artificial
# to-right constraint propagation (24), bidirectionality allows
#  intelligence (34), and an early PDP model (35) and dovetails
# neural models to implement a mutual constraint satisfaction
#  with an emerging perspective in cognitive neuroscience (36).
# process in which the representation of each word depends on
#  As humans process language, we construct a representation
# all other words. The attention mechanism distinguishes these
#  of the situation the language describes from the stream of
# models from earlier LSTM-based neural language models, and
#  words and other available information. Words and their se-
# is used in both bidirectional and left-to-right models. Atten-
#  quencing serve as clues to meaning (37) that jointly constrain
# tion has proven to be even more effective than the LSTM
#  the understanding of the situation and each object participat-
# mechanism in allowing networks to capture long-distance de-
#  ing in it (35). Consider this passage:
# pendencies. Rather than requiring information about a context
# word to reach a target word through an iteration of the LSTM John spread jam on a slice of bread. The knife had
# McClelland et al.: Language understanding in humans and machines 3
#
#
#
#
#
#
#
#
# PAGE 4  been dipped in poison. John ate the bread and soon
#  began to feel sick.
# We can make many inferences here: that the jam was spread
# with the poisoned knife, that some of the poison was trans-
# ferred to the bread, and that this may have led to John’s
# sickness. Note that the entities here are objects, not words,
# and the situation could instead be conveyed by a silent movie.
#  Evidence that humans construct situation representations
# comes from classic work by Bransford and colleagues (33, 38).
# This work demonstrates that (1) we understand and remember
# texts better when we can relate the statements in the text
# to a familiar situation; (2) information that conveys aspects
# of the situation can be provided by a picture accompanying
# the text; (3) the characteristics of the objects we remember
# depend on the situations in which they occurred in a text;
# (4) we represent in memory objects not explicitly mentioned
# in texts; and (5) after hearing a sentence describing spatial
# or conceptual relationships among objects, we retain mem-
# ory for these relationships rather than the linguistic input.
# Further, evidence from eye movements shows that people use
# linguistic and non-linguistic input jointly and immediately as
# they process language in context (39). For example, just after
# hearing The man will drink ... participants look at a full wine
# glass rather than an empty beer glass (40). After hearing The
# man drank, they look at the empty beer glass. Thus, language
# understanding involves constructing–in real time–a represen- Fig. 4. Proposed integrated understanding system (IUS). The blue box contains
# tation of the situation being described by language input, the neocortical system, with each oval forming an embedding (representation) of a
#  specific kind of information. Blue arrows represent learned connections that allow
# including the objects involved and their spatial relationships
#  the embeddings to constrain each other. The red box contains the medial temporal
# with each other, using visual and linguistic inputs. lobe system, thought to provide a network that stores an integrated embedding of the
#  neocortical system state. The red arrow represents fast-learning connections that
# The understanding system in the brain. Fig. 4 presents a de- bind the elements of this embedding together for later reactivation and use. Green
# piction of our proposed integrated understanding system. Our arrows connecting the red and blue ovals support bidirectional influences between
# proposal is both a theory of the brain basis of understanding the two systems. (A) and (B) are two example inputs discussed in the main text.
# and a proposed architecture for future language understanding
# research. It is largely consistent with proposals in (36). First,
# we focus on a part of the system, called the neocortical sys- match objects with their names or the sounds that they make,
# tem, that is sufficient to combine linguistic and non-linguistic and to pair objects that go together with each other, either
# input to understand the object and situation referred to upon from their names or from pictures. Models that capture these
# hearing a sentence containing the word bat while observing findings (43) treat this area as the hidden layer of an interac-
# a corresponding situation in the world. This system consists tive, recurrent network with bidirectional connections to other
# of the blue ovals (corresponding to pools of neurons in the layers corresponding to brain areas that represent different
# brain) and blue arrows (connections between these pools) in types of object properties including the object’s name. In these
# the figure. One population subserves a visual representa- models, an input to any of these other layers activates the cor-
# tion/embedding of the given situation, and another subserves responding pattern in the hidden layer, which in turn activates
# a non-semantic linguistic representation capturing the sound the corresponding patterns in the other layers, supporting, for
# structure (phonology) of co-occurring spoken language. The example, the ability to produce the name of an object from
# third represents objects participating in the situation, and visual input. Damage (simulated by removal of neurons in the
# the fourth represents the overall situation itself. Within each hidden layer) degrades the model’s representations, capturing
# pool, and between each connected pair of pools, the neurons the patterns of errors made by patients with the condition.
# are reciprocally interconnected via learning-dependent path-
# ways allowing mutual constraint satisfaction among all of the Situation representations. The situation representation specifies
# elements of each of the embedding types. Brain regions for the event or situation conveyed by visual and/or language
# representing visual and linguistic inputs are well-established, input. Evidence from behavioral studies indicates that con-
# and the evidence for their involvement in a mutual constraint struction of a situation representation can occur with or with-
# satisfaction process is substantial (41). Here we focus on the out language input (44) or through the convergent influence
# evidence for object and situation representations in the brain. of both sources of information (40). Cognitive neuroscience
#  research supports the idea that the situation representation
# Object representations. A brain area near the front of the tempo- arises in a set of interconnected brain areas primarily located
# ral lobe houses neurons whose activity provides an embedding in the frontal and parietal lobes (36, 45). In recent work, brain
# capturing the properties of an object someone is considering imaging data is used to analyze the time-varying patterns
# (42). Damage to this area impairs the ability to name objects, of neural activity that arise during the processing of a tem-
# to grasp objects correctly in service of their intended use, to porally extended event sequence. The activity patterns that
# McClelland et al.: Language understanding in humans and machines 4
#
#
#
#
#
#
#
#
# PAGE 5 represent corresponding events in a sequence are largely the previously are limited in this way. Though some models hold
# same, whether the information about the sequence comes from long word sequences in an active state, when one text is
# watching a movie, hearing or reading a narrative description, replaced with another, only the small connection adjustments
# or recalling the movie after having seen it (46, 47). described above remain, leaving these systems without access
#  to the specifics of the prior information.
# Situation-specific constraints. An important feature of our brain- The human brain contains a system that addresses this
# inspired proposal is the use of distinct situation and object limitation. Consider a situation in which someone sees a pre-
# representations, and the idea that the constraints on the par- viously unfamiliar object and hears a spoken statement about
# ticipating objects are mediated by the situation representation. it, as illustrated in Fig. 4B. The visual input provides one
# The advantage of this is that it allows these constraints to source of information about the object (a previously unfamiliar
# be situation-specific. For example, the dogs in the events de- animal), while the linguistic input provides its name. Humans
# scribed by the sentences the boy ran to the dog and the boy ran show robust learning after just two brief exposures to such
# from the dog are likely to be different, and a comprehender will pairings (51). This form of learning depends on the hippocam-
# represent them differently (38). In general, context-sensitivity pus and adjacent areas in the medial temporal lobes (MTL)
# is best captured by a mediating representation rather than of the brain (51). While details of the role of the MTL in
# direct associations among constituents (48). While BERT-like learning and memory continue to be debated (52, 53), there is
# models might partially capture such constraints implicitly, an consensus that the MTL is crucial for the initial formation of
# integrated situation representation may be more effective. new memories, including memories for specific events and their
#  In summary, the brain contains distinct areas that represent constituent objects and situations, while general knowledge,
# each input modality and the objects and situations conveyed the ability to understand language, and previously acquired
# through them, computing these representations through a skills are unaffected by MTL damage.
# mutual constraint satisfaction process combining language and The evidence from MTL damage suggests there is a fast
# other inputs. Emulating this architecture in machines could learning system in the MTL. According to complementary
# contribute to achieving human-level language understanding. learning systems theory (CLST) (54–56) this system (shown
# What would a computational instantiation of our system look in red in Fig. 4) provides an integrated representation of the
# like? It is likely that a biologically realistic version would understanding system state, and employs modifiable connec-
# differ in some ways from the most effective machine version. tions within the MTL (red arrow) that can change rapidly to
# Contemporary attention-based language models can deploy support new learning based on a single experience. The green
# attention over tens to thousands of words kept in their current arrows represent connections that carry information between
# system state, but evidence from brain imaging data collected the neocortical (blue) and MTL (red) systems so the systems
# during movie comprehension suggests that activation states in can influence each other.
# visual, speech, and object areas change rapidly as events unfold, Let us consider how, according to CLST, a human can learn
# while the brain state tends to be more constant, changing only about the numbat (see Fig. 4B) from an experience seeing
# at event boundaries in brain areas associated with situation it and hearing a sentence about it (56). The input to the
# representations (47). In humans, spanning longer temporal MTL is thought to be an embedding that captures (i.e., can
# windows, including multi-event narratives, appears to require be used to reconstruct) the patterns in the neocortical areas
# the complementary learning system we consider next. that arise from the experience. Networks within the MTL (not
#  shown) map the MTL input representation to a sparser one
# Complementary Learning Systems. Learning plays a crucial deep inside the MTL, maximizing distinctness and minimizing
# role in understanding. The knowledge in the connection interference among experiences (54). Large connection weight
# weights in the neural networks we have described is acquired changes within the MTL associate the elements of the sparse
# through the accumulation of very small adjustments based on representation with each other and with the MTL input repre-
# each experience. The connection weights gradually become sentation. When the person hears the word numbat in a later
# sensitive to subtle higher-order statistical relationships, taking situation, connections to the MTL from the neocortex activate
# more and more context into account as learning continues (49), neurons in the MTL input representation. The weight changes
# and exhibiting sensitivity both to general and recurring specific that occurred on prior exposure support the reconstruction
# information (e.g., names of close friends and famous people). of the complete MTL representation, and return connections
# In our proposed architecture, this gradual process occurs in to the neocortex then support approximate reconstruction of
# all the pathways represented by the blue arrows in Fig. 4, just the visual, speech, object and situation representations formed
# as it does in the artificial neural language models considered during the initial exposure to the numbat. These representa-
# above. However, this learning mechanism is not well suited to tions are the explicit memory for the prior experience, allowing
# acquiring new information rapidly, and attempting to learn the cortical network to use what it learned from one prior
# specific new information quickly by focused repetition leads exposure to contribute to understanding the new situation.
# to catastrophic interference with what is already known (50).
#  Yet, humans can often rely on information presented just Integrating information into the neocortex. How can knowledge ini-
# once at an arbitrary time in the past to inform our current tially dependent on the MTL be integrated into the neocor-
# understanding. Returning to the beer John left in the cooler, tex? According to CLST (55), the neocortex learns gradually
# to anticipate that John will not find the beer when he opens through interleaved presentations of new and familiar items;
# the cooler again, we must rely on information acquired when this process avoids interference of new items with what is al-
# we first heard about the beer being stolen. Such situations ready known. Interleaved learning can occur through ongoing
# are ubiquitous, and a learning system must be able to exploit experience, as would happen if, for example, we acquire a pet
# such information, but BERT and the other models described numbat that we then see every day, while continuing to have
# McClelland et al.: Language understanding in humans and machines 5
#
#
#
#
#
#
#
#
# PAGE 6 other experiences. Interleaving may also occur during rest and is often only approximately characterized by explicit tax-
# or sleep through reactivation and replay of patterns stored onomies, motivating use of emergent connection-based rather
# in the MTL: Indeed, spontaneous replay of short snippets of than hard-coded representational structures (60). A challenge,
# previously experienced episodes occurs within the MTL during then, is to achieve comparable performance with models in
# sleep and between behavioral episodes (see (56) for review). which these concept-based object and relational representa-
#  In summary, the human brain contains complementary tions emerge through learning.
# learning systems that support the simultaneous use of many
# sources of information as we seek to understand an experienced Embodied models for language understanding. Beyond the
# situation. One of these systems acquires an integrated system integration of vision and language, as illustrated in Fig. 4, we
# of knowledge gradually through interleaved learning, includ- see progress coming from an even fuller integration of many
# ing our knowledge of the meanings of words, the properties additional information sources. Every source provides a basis
# of frequently-encountered objects, and the characteristics of for distinct learning objectives and enables information that
# familiar situations. The other complements this system to is salient in one source to bootstrap learning and inference in
# allow information from specific experiences to be brought to the other. Important additional sources of information include
# bear on the interpretation of a current situation. non-language sound, touch and force-sensing, and information
#  about one’s own actions.
#  Incorporating additional information sources will allow an
# Toward an Artificial Integrated Understanding System
#  IUS to go beyond answering questions about static images.
# Here we consider current deep learning research that is taking Since image data has no temporal aspect, such models lack
# steps consistent with our IUS proposal, and point toward fu- experience of events or processes. While models that jointly
# ture directions that will be needed to achieve a truly integrated process video and language (61) may acquire some sensitiv-
# and fully functional understanding system. We begin within ity to event structure and commonplace causal relationships,
# the context of language grounded within concrete visual and these systems do not make choices affecting the world they
# physical situations, then consider the role of memory, and observe. Ultimately, an ability to link one’s actions to their
# finally turn to the extension of the approach to address under- consequences as one intervenes in the observed flow of events
# standing of more abstract objects, situations, and relations. and interacts with other agents should provide the strongest
#  basis for acquiring notions of cause and effect, of agency, and
# Mapping vision and language to representations of objects. of self and others.
# How might a model learn about situations that can occur These considerations motivate recent work on agent-
# in the world? The need for an artificial system of language based language learning in simulated interactive 3D environ-
# understanding to be grounded in the external world has long ments (62–65). In (66), an agent was trained to identify, lift,
# been discussed. An early example is Winograd’s SHRDLU carry and place objects relative to other objects in a virtual
# system (57), which produced and responded to language about room, as specified by simplified language instructions. At each
# a simulated physical world. Deep learning has enabled joint, time step, the agent received a first-person visual observation
# end-to-end training of perceptual input and language (i.e., in (pixel-based image) that it processed to produce a representa-
# a single synchronous optimization process). Recent advances tion of the scene. This was concatenated to the final state of
# with such models have greatly improved performance, resulting an LSTM that processed the instruction, then passed to an
# in applications transforming user experiences. When presented integrative LSTM whose output was used to select a motor
# with a photograph, networks can now answer questions such action. The agent gradually learned to follow instructions of
# as what is the man holding? or what color is the woman’s the form find a pencil, lift up a basketball and put the teddy
# shirt? (58), demonstrating an ability to combine information bear on the bed, encompassing 50 objects, and requiring up
# from vision and language to understand a class of situations. to 70 action steps to complete. Such instructions require the
#  A very recent model (59) explicitly represents the objects in construction of representations based on language stimuli that
# a scene, their properties, and their relations to other objects in enable the identification of objects and relations across space
# a designed scene graph with slots for objects, their properties, and time, and the integration of this information to inform mo-
# and relations. It encodes questions as a series of instructions tor behaviors. Importantly, without building in explicit object
# to find a target object or relation by searching the graph to representations, the system supported the interpretation of
# answer a query. For example, the question what is the object novel instructions. For instance, an agent trained to lift a set
# beside the yellow bowl? can be answered by finding the yellow of 20 objects in the environment, but only trained to put 10 of
# bowl, finding an object linked to it with the ‘beside’ relation, those in a specific location could place the remaining objects
# and then reading out this object’s identity. The approach in the same location on command with over 90% accuracy.
# advances the state of the art, though a large gap relative Neural models often fail to exhibit systematic generaliza-
# to humans remains. The model shares important properties tion, leading some to propose that more structure should be
# with our proposal in that it explicitly treats language input built in (67). While the agent’s level of systematicity does
# as querying the model’s representation of the objects in the not reach human levels, this work suggests that grounding lan-
# scene, and their conceptual properties. A natural extension guage learning can help support systematicity without building
# consistent with IUS would be to build up scene representations it in. Critically, the agent’s systematicity was contingent on
# using a combination of visual input and language, allowing the ego-centric, multimodal and temporally-extended expe-
# text to enrich the representations of objects and relations. rience of the agent. On the same set of generalization tests,
#  A question this work raises is whether to build structured both an alternative agent with a fixed perspective on a 2D grid
# representations into one’s model. This is advocated in (59), world and a static neural network classifier that received only
# but natural structure exhibits flexible embedding relationships individual still image stimuli exhibited significantly worse gen-
# McClelland et al.: Language understanding in humans and machines 6
#
#
#
#
#
#
#
#
# PAGE 7  tions under consideration can only be communicated through
#  language. What is the way forward toward developing models
#  that can understand such a complex situation?
#  Language may have evolved in part to support transmission
#  of complex, hierarchical knowledge about tools (71). How-
#  ever, utterances also had to support abstraction and complex
#  dependencies between concrete objects, as well as social re-
#  lationships between speakers. Words themselves provided a
#  new abstract substrate for characterizing other words (72).
#  Word embeddings are one implementation of this substrate:
#  they can characterize abstract words like justice and represents
#  without directly grounding them. In humans, encyclopedic
# Fig. 5. Left: the (allocentric) agent perspective in a 2D grid-world. The text indicates
# the language instruction, requiring the agent (white striped cell) to visit one of the
#  knowledge grounded in such representations can be acquired
# red figures and move it to the white square. Right: the first-person perspective of the in an MTL-dependent way from reading an encyclopedia arti-
# situated agent, addressing an equivalent task to the one posed in the grid world. cle just once. For machines, forming integrated system state
#  representations capturing the content and using a DNC-like
#  system for their storage and retrieval might provide a starting
# eralization that a fully situated agent (Fig. 5). This underlines place for enabling such knowledge to be acquired and used
# how affording neural networks access to rich, multi-modal effectively.
# interactive environments can stimulate the development of That said, words are uttered in real world contexts and there
# capacities that are essential for language learning. is a continuum between grounding and language-based linking
#  Despite these promising signs, achieving fully human levels for different words and different uses of words. For example,
# of generalization remains an important challenge. We propose career is not only linked to other abstract words like work and
# that incorporating an MTL-like fast learning system will help specialization but also to more grounded concepts such as path
# address this by allowing new words to be linked to the corre- and its extended metaphorical use for discussing the means to
# sponding object from just a single episode supporting use of achieve goals (72). Embodied, simulation-based approaches
# the word to refer to the referent in other situations. to meaning (73, 74) build on this observation to bridge from
#  concrete to abstract situations via metaphor. They posit
# An artificial fast learning system. What might a fast learning that understanding words like grasp is directly linked to neural
# system in an implementation of an integrated understanding representations of the action of grabbing and that this circuitry
# system look like? The memory system in the differentiable is recruited for understanding the word in contexts such as
# neural computer (DNC) (68) is one possibility. These systems grasping an idea. We consider situated agents as a critical
# store embeddings derived from past episodes in slots that catalyst for learning about how to represent and compose
# could store Integrated System State representations like those concepts pertaining to spatial, physical and other perceptually
# we attribute to the human MTL. Alternatively, they could immediate phenomena—thereby providing a grounded edifice
# store the entire ensemble of states across the visual, speech, that can connect to both the low level brain circuitry for motor
# object, and situation representations. Though we do not action and to representations derived primarily from language.
# believe the brain has a separate slot for each memory, it can
# be useful to model it as though it does (56), and artificial Conclusion. Language does not stand alone. The integrated
# systems with indefinite capacity could exceed human abilities understanding system in the brain connects language to rep-
# in this regard. How might the retrieval of relevant information resentations of objects and situations and enhances language
# work in such a system? The DNC employs a querying system understanding by exploiting the full range of our multi-sensory
# similar to the one in BERT and to proposals in the human experience of the world, our representations of our motor
# memory literature, whereby the representation retrieved from actions, and our memory of previous situations. We have ar-
# the MTL is weighted by the degree of match between a query gued that the next generation language understanding system
# (which we would treat as coming from the neocortex) and each should emulate this system in the brain and we have sketched
# vector stored in memory. Close matches are favored in this some aspects of the form such a system might take. While
# computation (69), so that when there is a unique match (such we have emphasized understanding of concrete situations, we
# as a single memory containing a once seen word like numbat), have argued that understanding more abstract language builds
# the corresponding object and situation representation could upon this concrete foundation, pointing toward the possibility
# be retrieved. Retrieval could be based on a combination of that it may someday be possible to build artificial systems that
# context and item information, similar to human memory (70). understand abstract situations far beyond the concrete and
# Working out the details of such a system presents an exciting the here-and-now. In sum, we have proposed that modeling
# research direction for the future. the integrated understanding system in the brain will take us
#  closer to capturing human-level language understanding and
# Beyond concrete situations. Our discussion has focused pri- intelligence.
# marily on concrete situations. However, language allows us to
# discuss abstract ideas and situations, where grounding in the ACKNOWLEDGMENTS. This article grew out of a workshop
# physical world can be very indirect and our learning about organized by HS at Meaning in Context 3, Stanford University,
#  September 2017. We thank Chris Potts for discussion. HS was
# it comes primarily from language-based materials. Consider,
#  supported by ERC Advanced Grant #740516.
# for example, an understanding of Brexit. Concrete events
# involving actual people have occurred, but the issues and ques-
# McClelland et al.: Language understanding in humans and machines 7
# PAGE 8  1. Wu Y, et al. (2016) Google’s neural machine translation system: Bridging the gap between world knowledge: Linking anticipatory (and other) eye movements to linguistic processing.
#  human and machine translation. -. Journal of Memory and Language 57(4):502–518.
#  2. Rosenblatt F (1961) Principles of neurodynamics. perceptrons and the theory of brain mech- 41. McClelland JL, Mirman D, Bolger DJ, Khaitan P (2014) Interactive activation and mutual con-
#  anisms. (Spartan Books, Cornell University, Ithaca, New York). straint satisfaction in perception and cognition. Cognitive science 38(6):1139–1189.
#  3. Rumelhart DE, McClelland JL, the PDP research group (1986) Parallel Distributed Process- 42. Patterson K, Nestor PJ, Rogers TT (2007) Where do you know what you know? the represen-
#  ing. Explorations in the Microstructure of Cognition. Volume 1: Foundations. (The MIT Press, tation of semantic knowledge in the human brain. Nature Reviews Neuroscience 8(12):976.
#  Cambridge, MA). 43. Rogers TT, et al. (2004) Structure and deterioration of semantic memory: a neuropsycholog-
#  4. Rumelhart DE, McClelland JL (1986) On learning the past tenses of English verbs in Parallel ical and computational investigation. Psychological review 111(1):205–235.
#  Distributed Processing. Explorations in the Microstructure of Cognition. Volume 2: Psycho- 44. Zwaan RA, Radvansky GA (1998) Situation models in language comprehension and memory.
#  logical and Biological Models, eds. McClelland JL, Rumelhart DE, the PDP Research Group. Psychological bulletin 123(2):162–185.
#  (MIT Press), pp. 216–271. 45. Ranganath C, Ritchey M (2012) Two cortical systems for memory-guided behaviour. Nature
#  5. Rumelhart DE (1977) Toward an interactive model of reading in Attention & Performance VI, Reviews Neuroscience 13:713. Review Article.
#  ed. Dornic S. (LEA, Hillsdale, NJ), pp. 573–603. 46. Zadbood A, Chen J, Leong Y, Norman K, Hasson U (2017) How we transmit memories to
#  6. McClelland JL, Rumelhart DE (1981) An interactive activation model of context effects in letter other brains: Constructing shared neural representations via communication. Cerebral Cor-
#  perception: I. an account of basic findings. Psychological review 88(5):375. tex 27(10):4988–5000.
#  7. Hopfield JJ (1982) Neural networks and physical systems with emergent collective computa- 47. Baldassano C, et al. (2017) Discovering event structure in continuous narrative perception
#  tional abilities. Proceedings of the national academy of sciences 79(8):2554–2558. and memory. Neuron 95(3):709–721.
#  8. Ackley DH, Hinton GE, Sejnowski TJ (1985) A learning algorithm for boltzmann machines. 48. Hinton GE (1981) Implementing semantic networks in parallel hardware in Parallel Models of
#  Cognitive science 9(1):147–169. Associative Memory, eds. Hinton GE, Anderson JA. (Erlbaum), pp. 161–187.
#  9. Elman JL (1990) Finding structure in time. Cognitive Science 14:179–211. 49. Cleeremans A, McClelland JL (1991) Learning the structure of event sequences. Journal of
# 10. Gold EM (1967) Language identification in the limit. Information and control 10(5):447–474. Experimental Psychology: General 120(3):235.
# 11. Elman JL (1991) Distributed representations, simple recurrent networks, and grammatical 50. McCloskey M, Cohen NJ (1989) Catastrophic interference in connectionist networks: The
#  structure. Mach. Learn. 7(2/3):195–225. sequential learning problem in Psychology of learning and motivation. (Elsevier) Vol. 24, pp.
# 12. Hochreiter S, Bengio Y, Frasconi P, Schmidhuber J (2001) Gradient flow in recurrent nets: the 109–165.
#  difficulty of learning long-term dependencies in A Field Guide to Dynamical Recurrent Neural 51. Warren DE, Duff MC (2019) Fast mappers, slow learners: Word learning without hippocam-
#  Networks, eds. Kremer SC, Kolen JF. (IEEE Press). pus is slow and sparse irrespective of methodology. Cognitive neuroscience pp. 1–3.
# 13. Hochreiter S, Schmidhuber J (1997) Long short-term memory. Neural computation 52. Squire LR (1992) Memory and the hippocampus: a synthesis from findings with rats, mon-
#  9(8):1735–1780. keys, and humans. Psychological review 99(2):195.
# 14. Collobert R, et al. (2011) Natural language processing (almost) from scratch. Journal of 53. Yonelinas A, Ranganath C, Ekstrom A, Wiltgen B (2019) A contextual binding theory of
#  Machine Learning Research 12(Aug):2493–2537. episodic memory: systems consolidation reconsidered. Nature Reviews Neuroscience.
# 15. Mikolov T, Sutskever I, Chen K, Corrado GS, Dean J (2013) Distributed representations of 54. Marr D (1971) Simple memory: a theory for archicortex. Philosophical Transactions of the
#  words and phrases and their compositionality in Neural Information Processing Systems. pp. Royal Society of London B: Biological Sciences 262(841):23–81.
#  3111–3119. 55. McClelland JL, McNaughton BL, O’Reilly RC (1995) Why there are complementary learning
# 16. Simpson GB (1981) Meaning dominance and semantic context in the processing of lexical systems in the hippocampus and neocortex: Insights from the successes and failures of
#  ambiguity. Journal of verbal learning and verbal behavior 20(1):120–136. connectionist models of learning and memory. Psychological Review 102(3):419–457.
# 17. Rudolph M, Ruiz F, Blei D (2017) Structured embedding models for grouped data in Advances 56. Kumaran D, Hassabis D, McClelland JL (2016) What learning systems do intelligent agents
#  in Neural Information Processing Systems. need? Complementary learning systems theory updated. Trends in Cognitive Sciences
# 18. Peters ME, et al. (2018) Deep contextualized word representations. CoRR abs/1802.05365. 20(7):512–534.
# 19. Vaswani A, et al. (2017) Attention is all you need in Advances in Neural Information Process- 57. Winograd T (1972) Understanding natural language. Cognitive psychology 3(1):1–191.
#  ing Systems 30. (Curran Associates, Inc.), pp. 5998–6008. 58. MacLeod H, Bennett CL, Morris MR, Cutrell E (2017) Understanding blind people’s experi-
# 20. Devlin J, Chang MW, Lee K, Toutanova K (2018) BERT: Pre-training of Deep Bidirectional ences with computer-generated captions of social media images in Proceedings of the 2017
#  Transformers for Language Understanding. ArXiv e-prints. CHI Conference on Human Factors in Computing Systems. (ACM), pp. 5988–5999.
# 21. Yang Z, et al. (2019) Xlnet: Generalized autoregressive pretraining for language understand- 59. Hudson DA, Manning CD (2019) Learning by abstraction: The neural state machine. arXiv
#  ing. CoRR abs/1906.08237. preprint arXiv:1907.03950.
# 22. Dehghani M, Gouws S, Vinyals O, Uszkoreit J, Kaiser L (2018) Universal transformers. CoRR 60. Rumelhart DE, Smolensky P, McClelland JL, Hinton G (1986) Pdp models of schemata and
#  abs/1807.03819. sequential thought processes in pdp models. Parallel distributed processing: Explorations in
# 23. Uszkoreit J (2017) Transformer: A novel neural network architecture for language understand- the microstructure of cognition 2:3–57.
#  ing, https://ai.googleblog.com/2017/08/transformer-novel-neural-network.html. 61. Yu H, Wang J, Huang Z, Yang Y, Xu W (2016) Video paragraph captioning using hierarchical
# 24. Radford A, Narasimhan K, Salimans T, Sutskever I (2018) Improving language understanding recurrent neural networks in Proceedings of the IEEE conference on computer vision and
#  by generative pre-training. OpenAI Preprint. pattern recognition. pp. 4584–4593.
# 25. Devlin J, Chang MW, Lee K, Toutanova K (2018) Bert: Pre-training of deep bidirectional 62. Hermann KM, et al. (2017) Grounded language learning in a simulated 3d world. arXiv
#  transformers for language understanding. arXiv preprint arXiv:1810.04805. preprint arXiv:1706.06551.
# 26. Wang A, et al. (2018) Glue: A multi-task benchmark and analysis platform for natural lan- 63. Das R, Zaheer M, Reddy S, McCallum A (2017) Question answering on knowledge bases
#  guage understanding. arXiv preprint arXiv:1804.07461. and text using universal schema and memory networks in Proceedings of the 55th Annual
# 27. Wang A, et al. (2019) Superglue: A stickier benchmark for general-purpose language under- Meeting of the Association for Computational Linguistic. pp. 358–365.
#  standing systems. arXiv preprint arXiv:1905.00537. 64. Chaplot DS, Sathyendra KM, Pasumarthi RK, Rajagopal D, Salakhutdinov R (2017)
# 28. Levesque H, Davis E, Morgenstern L (2012) The winograd schema challenge in Thirteenth Gated-attention architectures for task-oriented language grounding. arXiv preprint
#  International Conference on the Principles of Knowledge Representation and Reasoning. arXiv:1706.07230.
# 29. Raffel C, Shazeer N, Roberts A, , et al. (2019) Exploring the limits of transfer learning with a 65. Oh J, Singh S, Lee H, Kohli P (2017) Zero-shot task generalization with multi-task deep rein-
#  unified text-to-text transformer. arXiv preprint arXiv:1910.10683. forcement learning in Proceedings of the 34th International Conference on Machine Learning-
# 30. Jia R, Liang P (2017) Adversarial examples for evaluating reading comprehension systems in Volume 70. (JMLR. org), pp. 2661–2670.
#  Proceedings of the 2017 Conference on Empirical Methods in Natural Language Processing. 66. Hill F, et al. (2019) Emergent systematic generalization in a situated agent. arXiv preprint
#  (Association for Computational Linguistics), pp. 2021–2031. arXiv:1910.00571.
# 31. Lakoff G (1987) Women, Fire, and Dangerous Things. (The University of Chicago Press, 67. Lake BM, Salakhutdinov R, Tenenbaum JB (2015) Human-level concept learning through
#  Chicago). probabilistic program induction. Science 350(6266):1332–1338.
# 32. Langacker RW (1987) Foundations of cognitive grammar: Theoretical prerequisites. (Stan- 68. Graves A, et al. (2016) Hybrid computing using a neural network with dynamic external mem-
#  ford university press) Vol. 1. ory. Nature 538(7626):471–476.
# 33. Bransford JD, Johnson MK (1972) Contextual prerequisites for understanding: Some in- 69. Hintzman DL (1984) Minerva 2: A simulation model of human memory. Behavior Research
#  vestigations of comprehension and recall. Journal of verbal learning and verbal behavior Methods, Instruments, & Computers 16(2):96–101.
#  11(6):717–726. 70. Polyn SM, Norman KA, Kahana MJ (2009) A context maintenance and retrieval model of
# 34. Schank RC (1983) Dynamic memory: A theory of reminding and learning in computers and organizational processes in free recall. Psychological review 116(1):129.
#  people. (Cambridge University Press). 71. Stout D, Chaminade T (2012) Stone tools, language and the brain in human evolution. Philos
# 35. John MFS, McClelland JL (1990) Learning and applying contextual constraints in sentence Trans R Soc Lond B Biol Sci 367(1585):75–87.
#  comprehension. Artificial Intelligence 46(1):217 – 257. 72. Bryson J (2008) Embodiment vs. memetics. Mind and Society 7(1):77–94.
# 36. Hasson U, Egidi G, Marelli M, Willems RM (2018) Grounding the neurobiology of language 73. Lakoff G, Johnson M (1980) Metaphors We Live By. (University of Chicago, Chicago, IL).
#  in first principles: The necessity of non-language-centric explanations for language compre- 74. Feldman J, Narayanan S (2004) Embodied meaning in a neural theory of language. Brain
#  hension. Cognition 180:135–157. and Language 89:385–392.
# 37. Rumelhart DE (1979) Some problems with the notion that words have literal meanings in
#  Metaphor and thought, ed. Ortony A. (Cambridge Univ. Press, Cambridge, UK), pp. 71–82.
# 38. Barclay J, Bransford JD, Franks JJ, McCarrell NS, Nitsch K (1974) Comprehension and se-
#  mantic flexibility. Journal of Verbal Learning and Verbal Behavior 13(4):471 – 481.
# 39. Tanenhaus MK, Spivey-Knowlton MJ, Eberhard KM, Sedivy JC (1995) Integration of visual
#  and linguistic information in spoken language comprehension. Science pp. 1632–1634.
# 40. Altmann GT, Kamide Y (2007) The real-time mediation of visual attention by language and
# McClelland et al.: Language understanding in humans and machines 8

# %%
# Shitty experiments with PyPDF2
import PyPDF2


read_pdf = PyPDF2.PdfFileReader(os.path.join(sample_pdf_dir, '2019.pdf'))
number_of_pages = read_pdf.getNumPages()
for i in range(number_of_pages):
    page = read_pdf.getPage(i)
    page_content = page.extractText()
    # print(page_content.encode('utf-8'))
    print(page_content)
# Out:
# ExtendingMachineLanguageModelstoward
# Human-LevelLanguageUnderstanding
# JamesL.McClelland
# a,b,2
# ,
# FelixHill
# b,2
# ,
# MajaRudolph
# c,2
# ,
# JasonBaldridge
# d,1,2
# ,and
# HinrichSchütze
# e,1,2
# a
# StanfordUniversity,Stanford,CA94305,USA;
# b
# DeepMind,LondonN1C4AG,UK;
# c
# BoschCenterforArIntelligence,Renningen,71272,Germany;
# d
# GoogleResearch,
# Austin,TX78701,USA;
# e
# LMUMunich,Munich,80538,Germany
# ThismanuscriptwascompiledonDecember13,2019
# Languageiscentraltohumanintelligence.Wereviewrecentbreak-
# throughsinmachinelanguageprocessingandconsiderwhatre-
# mainstobeachieved.Recentapproachesrelyondomaingeneral
# principlesoflearningandrepresentationcapturedinarneu-
# ralnetworks.Mostcurrentmodels,however,focustoocloselyon
# languageitself.Inhumans,languageispartofalargersystemfor
# acquiring,representing,andcommunicatingaboutobjectsandsit-
# uationsinthephysicalandsocialworld,andfuturemachinelan-
# guagemodelsshouldemulatesuchasystem.Wedescribeexist-
# ingmachinemodelslinkinglanguagetoconcretesituations,and
# pointtowardextensionstoaddressmoreabstractcases.Human
# languageprocessingexploitscomplementarylearningsystems,in-
# cludingadeepneuralnetwork-likelearningsystemthatlearnsgrad-
# uallyasmachinesystemsdo,aswellasafast-learningsystemthat
# supportslearningnewinformationquickly.Addingsuchasystemto
# machinelanguagemodelswillbeanimportantfurthersteptoward
# trulyhuman-likelanguageunderstanding.
# LanguageUnderstanding
# j
# NaturalLanguageProcessing
# j
# Situation
# Models
# j
# MachineLanguageModels
# j
# BrainSystemforUnderstanding
# Manyofthemostimpressiverecentsuccessesofmachinein-
# telligencehaveappearedinthedomainoflanguage.Machines
# cannowbetteridentifythewordswespeakandrespondin
# evermorenaturalsoundingvoices.Moreimpressivestillis
# modernmachinetranslation(
# 1
# ).Anyonewithasmartphone
# hasaccesstoapplicationsthatallowthemtosayasentencein
# onelanguageandthenseeandhearitstranslationinanother.
# Humanabilitystillfarexceedsmachinesinmostlanguage
# tasks,butthesesystemsworkwellenoughtobeusedby
# billionsofpeopleeveryday.
# Whatunderliesthesesuccesses,andwhatlimitationsdo
# thesesystemsface?Wearguethatsuccessestodatecomefrom
# evermoree˙ectivemethodsforexploitingprinciplesofneural
# computationthathumanlanguageusersalsoexploit.Wethen
# notethattheworkremainslimitedinthatitlargelytreats
# languageseparatelyfromthelargertaskofunderstanding
# theworldaroundus.Thisleadsustoproposeanintegrated
# approachtobuildingasystemthattrulyunderstands,inwhich
# languageplaysakeyroleinconcertwithothersourcesofinput.
# Wediscussthechallengesfacingfurtherdevelopmentofthe
# approachandproposefuturestepstowardaddressingthese
# challenges.
# PrinciplesofNeuralComputation
# Theprinciplesofneuralcomputationaredomaingeneralprin-
# ciplesinspiredbythehumanbrain.Theywere˝rstarticulated
# inthe1950s(
# 2
# )andfurtherdevelopedinthe1980sinthe
# ParallelDistributedProcessing(PDP)frameworkformodeling
# cognition(
# 3
# ).Acentralideaofthisapproachisthatstruc-
# tureinlanguageandothercognitivedomainsisanemergent
# phenomenon,capturedinlearnedconnectionweightsandre-
# sultingincontext-sensitive,distributedrepresentationswhose
# characteristicsre˛ectagradual,input-statisticsdependent,
# learningprocess(
# 4
# ).Themodelstreatthesymbolsandrules
# ofclassicallinguistictheoryasconsequencesofprocessingand
# learning,notentitieswhosestructuremustbebuiltin.Instead
# ofdiscretesymbolsforlinguisticunits,thesemodelsrelyon
# patternsofactivityoftencalled
# embeddings
# overarraysof
# neuron-likeprocessingunits.Insteadofexplicitsystemsof
# rules,theyrelyonlearnedmatricesofconnectionweightsto
# mappatternsononesetofunitsintopatternsonothers.
# Anotherkeyprincipleismutualconstraintsatisfaction(
# 5
# ).
# Forexample,themeaningofasentencedependsonitsstruc-
# ture(itsorganizationintoconstituentphrases);butsotoocan
# thestructuredependonthemeaning.Considerthesentence
# A
# boyhitamanwitha__
# .Ifthemissingwordis
# bat
# ,
# withabat
# isreadaspartofaverbphraseheadedby
# hit
# ,andspeci˝esthe
# instrumentusedtocarryouttheaction.Butif
# beard
# ˝llsthe
# blank,
# withabeard
# isapartofanounphrasedescribingwho
# washit.Eventhesegmentationofspokenorwrittenlanguage
# intoelementarysegments(e.g.,letters)dependsinparton
# meaningandcontext,asillustratedinFig.
# 1
# .Rumelhart(
# 5
# )
# sketchedaninteractivemodeloflanguageunderstandingin
# whichestimatesofprobabilitiesaboutallaspectsofaninput
# constrainestimatesoftheprobabilityofeveryotheraspect.
# Theideawascapturedinamodelofcontexte˙ectsinper-
# ception(
# 6
# ).Laterwork(
# 7
# ,
# 8
# )linkedtheseideastoenergy
# minimizationinstatisticalphysics.Neurallanguagemodeling
# research,whichwenowdescribe,incorporatestheseprinciples.
# NeuralLanguageModeling
# AnEarlyNeuralLanguageModel.
# Elman(
# 9
# )builtontheprin-
# ciplesabovetodemonstratehowneuralmodelscancapture
# keycharacteristicsoflanguagestructurethroughlearning,a
# featonceconsideredimpossible(
# 10
# ).Themodelprovidesa
# startingpointforunderstandingrecentdevelopments.Elman
# usedtherecurrentneuralnetworkshowninFig.
# 2
# a.The
# networkwastrainedtopredictthenextwordinasequence
# (
# w
# (
# t
# +1)
# )basedonthecurrentword(
# w
# (
# t
# )
# )anditsown
# hidden
# (thatis,learnedinternal)representationfromtheprevious
# timestep(
# h
# (
# t
#
# 1)
# ).Thesetwoinputsareeachmultiplied
# byamatrixofconnectionweights(representedbythearrows
# labeled
# W
# hi
# and
# W
# hh
# )toproducevectorsthatareaddedto
# produceavectorofinputstothehiddenlayerofunits.The
# JM,FH,MR,JB,andHSwrotethepaper.
# Theauthorsdeclarenoofinterest.
# 1
# J.B.andH.S.contributedequally.
# 2
# Towhomcorrespondenceshouldbeaddressed.E-mail:jlmccstanford.edu,felixhill@google.com,
# marirudolph@gmail.com,jasonbaldridge@google.comorinquiries@cislmu.org
# 1
# arXiv:1912.05877v1  [cs.CL]  12 Dec 2019
# Fig.1.
# Twohandwrittensentencesillustratinghowcontextthe
# oflettersinwrittentext.Thevisualinputwereadas
# went
# inthesentenceand
# event
# inthesecondisthesamebitofRumelhart'shandwriting,cutandpastedinto
# eachofthetwocontexts.Reprintedfrom(
# 5
# ).
# elementsofthisvectorundergoatransformationlimitingthe
# rangeofactivationvalues,resultinginthehiddenlayerrepre-
# sentation.Thisinturnismultipliedwiththematrixofweights
# totheoutputlayerfromthehiddenlayer(
# W
# oh
# )togeneratea
# vectorusedtopredicttheprobabilityofeachofthepossible
# successorwords.Learninginthisandotherneuralmodelsis
# basedonthediscrepancybetweenthenetwork'soutputand
# theactualnextword;thevaluesoftheconnectionweights
# areadjustedbyasmallamounttoreducethediscrepancy.
# Thenetworkiscalledrecurrentbecausethesameconnection
# weights(denotedbyarrowsinthe˝gure)areusedtoprocess
# eachsuccessiveword;thehiddenrepresentation
# h
# (
# t
# )
# becomes
# thecontextrepresentation
# h
# (
# t
#
# 1)
# forthenexttimestep.
# Elmandemonstratedtwocrucial˝ndings.First,aftertrain-
# inghisnetworktopredictthenextwordinsimplesentenceslike
# maneatsbread
# ,
# dogchasescat
# ,and
# girlsleeps
# ,thenetwork's
# representationscapturedthesyntacticdistinctionbetween
# nounsandverbs(
# 9
# ).Italsocapturedinterpretablesubcate-
# gories,asshownbyahierarchicalclusteringofthehidden-layer
# pattern(
# h
# (
# t
# )
# )foreachwordinthetrainingmaterials(Fig.
# 2
# b).
# Thisillustratesakeyfeatureoflearnedrepresentationsinneu-
# ralmodels:theycapturespeci˝caswellasgeneralorabstract
# information.Byusingadi˙erentlearnedrepresentationfor
# eachword,thespeci˝cpredictiveconsequencesofthatword
# canbeexploited.Becauserepresentationsforwordsthatmake
# similarpredictionsaresimilar,andbecauseneuralnetworks
# exploitsimilarity,thenetworkcanshareknowledgeabout
# predictionsamongrelatedwords.Second,Elman(
# 11
# )used
# bothsimplesentenceslike
# boychasesdogs
# andmorecomplex
# oneslike
# boywhoseesgirlschasesdogs
# .Inthemorecomplex
# case,theverb
# chases
# mustagreewiththe˝rstnoun(
# boy
# ),not
# theclosestnoun(
# girls
# ),sincethesentencecontainsamain
# clause(
# boychasesdogs
# )interruptedbyanembeddedclause
# (
# boy[who]seesgirls
# ).Themodellearnedtopredicttheverb
# formcorrectlydespitetheinterveningclause,showingthatit
# acquiredsensitivitytothesyntacticstructureoflanguage,and
# notjustlocalco-occurrencestatisticsinitslearnedconnections
# anddistributedrepresentations.
# ScalingUptoProcessNaturalText.
# Elman's
# thenextwordinabeencentraltoneurallan-
# guagemodeling.However,Elmantrainedhisnetworkswith
# onlytinyfragmentsofwhatweree˙ectivelytoylanguages.
# Formanyyears,itseemedtheywouldnotscaleup.Beginning
# about10yearsago,advancesinmachinelanguageprocess-
# ingbegantoovercomethislimitationforneuralmodels.We
# describetwocrucialdevelopmentsnext.
# Long-distancedependenciesandpretrainedwordembeddings.
# A
# challengeforlanguagepredictionistheinde˝nitelengthof
# Fig.2.
# (a)Elman's(1990)simplerecurrentnetworkand(b)hishierarchicalclustering
# oftherepresentationsitlearned,reprintedfrom(
# 9
# ).
# thecontextthatmightberelevant.Considerthispassage:
# Johnputsomebeerinacoolerandwentoutwithhis
# friendstoplayvolleyball.Soonafterheleft,someone
# tookthebeeroutofthecooler.Johnandhisfriends
# werethirstyafterthegame,andwentbacktohis
# placeforsomebeers.WhenJohnopenedthecooler,
# hediscoveredthatthebeerwas___.
# Hereareaderexpectsthemissingwordtobe
# gone
# .Yetif
# wereplaced
# someonetookthebeer
# with
# someonetooktheice
# theexpectedwordwouldbe
# warm
# instead.Furthermore,any
# amountofadditionaltextbetween
# beer
# and
# gone
# wouldnot
# changethepredictiverelationship.Elman'snetworkcould
# takeonlyafewwordsofcontextintoaccount,re˛ectinga
# largerchallengeknownasthe
# vanishinggradient
# problem(
# 12
# ).
# Inessence,themagnitudeofthelearningsignalthatdeter-
# minestheadjustmentstoconnectionweightstendstodecrease
# exponentiallyasthenumberoflayersofweightsbetweenan
# inputandanoutputincreases.Thedevelopmentofneural
# networkmodulescalledLong-Short-Term-Memory(LSTM)
# modules(
# 13
# )thatpartiallyovercamethislimitationwasthere-
# forecrucial,greatlyincreasingthecontextualrangeofneural
# models.Inanothercrucialdevelopment,researchersbegan
# tousepre-trainedwordembeddingsderivedfromlearning
# predictiverelationshipsamongwords(
# 14
# ,
# 15
# ).Whentraining
# aneuralmodelforaspeci˝ctask,suchembeddingscouldthen
# beusedtodirectlyrepresenttrainingwordsinthemodel's
# input.Theembeddingswerebasedontheaggregatestatistics
# oflargetextcorpora,andcapturedbothgeneralandspeci˝c
# predictiverelationships,supportinggeneralizationatbothgen-
# eralandspeci˝clevels.Usingtheseembeddings,task-focused
# modelstrainedwithrelativelysmalldatasetscouldgeneralize
# whattheylearnedfromtrainingonfrequentwords(suchas
# sofa
# )toinfrequentwordswithsimilarpredictiverelationships
# (suchas
# settee
# ).
# Alimitationoftheaboveapproachisthatthesamerep-
# resentationofawordisusedeverytimeitoccurs,regardless
# ofcontext.However,inlinewiththeprincipleofmutual
# constraintsatisfaction,humansinterpretwords,includingam-
# biguouswordslike
# bank
# ,inaccordancewiththecontext(
# 16
# ),
# rapidlyassigningacontextuallyappropriatemeaningtoeach
# wordbasedonallotherwords.A˝xedembeddingalsolimits
# predictingotherwords;thepredictiveimplicationoftheword
# bank
# dependsonwhichkindofbankisinvolved.Initialsteps
# McClellandetal.:Languageunderstandinginhumansandmachines2
# Fig.3.
# High-leveldepictionofonestageofthebidirectionalattentionarchitecture,
# shownconstructingacontextuallyappropriaterepresentationof
# bank
# basedonother
# wordsinthesamesentence.Diagonallinesshowhowinputsfromotherpositions
# reach
# bank
# 'sposition;thesameoccursatallwordpositions.Seetextfordetails.
# towardcontextsensitivity(
# 17
# )recognizethislimitation.We
# considerafullersolutioninthenextsection.
# Attentionandfullycontextualizedembeddings.
# Breakthroughsin
# neurallanguagemodelinghavecomefromrecentmodelsthat
# constructfullycontextualizedwordrepresentations(
# 18
#
# 22
# ).
# Themodelsrepresentwordsviaamutualconstraintsatis-
# factionprocessinwhicheachwordinatextspanin˛uences
# therepresentationofeveryotherword.BERT(
# 20
# )isakey
# modelinthisclass,illustratedinFig.
# 3
# asitencodestheend
# ofthesentence
# Johnreachedthebankoftheriver
# (example
# from(
# 23
# )).Aninitialcontext-independentrepresentationof
# eachwordis˝rstcombinedwithapositionalrepresentation
# (bottomrowofboxesinthe˝gure).Then,aseparatecopyof
# thesameneuralnetworkmoduleupdatestherepresentationin
# eachpositionwithinputfromallotherpositions.Thisprocess
# usesqueries(red)ateachpositionthatarecomparedtokeys
# (yellow)atallpositionstoformweightings(mauveboxes)that
# determinehowstronglythevalues(blue)fromeachposition
# contributetothecombinedattentionvectors(greyboxes)that
# providecontext-sensitivity.Thecomputationiteratesover
# manylayers,allowingwordswhoserepresentationshavebeen
# in˛uencedbytheircontexttoin˛uencetherepresentationsof
# otherwords.Theprocessallowsselectionamongalternative
# distinctmeaningsofawordlike
# bank
# aswellasgradedshading
# ofwordmeaningbycontext,forexampleassigningdi˙erent
# emotionalvalancetothedogsin
# thedogwaggeditstail
# and
# thedogsnarled
# .
# Keyingredientsofthecontemporarymodelsare(i)
# bidi-
# rectionality
# ofinformation˛owduringprocessingand(ii)an
# attention
# mechanism,whichreplacestheLSTMmechanismto
# enhancetheexploitationofcontext.Bidirectionalitymatters
# becausethemeaningofawordincontextdependsonwhat
# comesafteritaswellaswhatcomesbefore;intheexample
# sentence,thelastword,
# river
# ,determinesthemeaningof
# bank
# .
# Whileitisremarkablehowmuchcanbedonewithstrictlyleft-
# to-rightconstraintpropagation(
# 24
# ),bidirectionalityallows
# neuralmodelstoimplementamutualconstraintsatisfaction
# processinwhichtherepresentationofeachworddependson
# allotherwords.Theattentionmechanismdistinguishesthese
# modelsfromearlierLSTM-basedneurallanguagemodels,and
# isusedinbothbidirectionalandleft-to-rightmodels.Atten-
# tionhasproventobeevenmoree˙ectivethantheLSTM
# mechanisminallowingnetworkstocapturelong-distancede-
# pendencies.Ratherthanrequiringinformationaboutacontext
# wordtoreachatargetwordthroughaniterationoftheLSTM
# foreveryinterveningword,thecontextreachesthetarget
# directly.Likewise,gradientlearningsignalsskipovertheinter-
# veningwords,avoidingthedissipationoflearningsignalthat
# wouldotherwiseoccur.
# BERT-basedmodelshaveproducedremarkableimprove-
# mentsonawiderangeoflanguagetasks(
# 25
# ,
# 26
# ).Themodels
# canbepre-trainedonmassivetextcorpora,providinguseful
# representationsforsubsequenttasksforwhichlittlespeci˝c
# trainingdataexists(
# 27
# ).Thesemodelsseemtocapturesyn-
# tactic,semanticandworldknowledgeandtheyarebeginning
# toaddresstasksoncethoughtbeyondtheirreach.Forex-
# ample,
# WinogradSchemachallenge
# (
# 28
# )requiresdetermining
# thereferentofapronoun(here
# it
# )inasentencesuchas
# The
# trophydidnot˝tinthesuitcasebecauseitwastoo___
# .Fora
# person,worldknowledgetellsusthatifthemissingwordis
# big
# thereferentmustbethetrophy,butifitis
# small
# thereferent
# mustbethesuitcase.Thelatestmodelsachieveever-higher
# scoresonbenchmarksincludingvariantsoftheWinogradchal-
# lenge(
# 29
# ).However,variantsoftestmaterialsthatdonot
# foolhumanscontinuetostymieeventhebestmodels(
# 30
# ),and
# furtherre˝nementsinthemodelsandtheirassessmentwillbe
# requiredbeforeitwillbeclearwhatsuchmodelscanachieve.
# TheHumanIntegratedUnderstandingSystem(IUS)
# Situationsandobjects.
# Despitethesuccessesofneurallan-
# guagemodeling,animportantlimitationisthatthesemodels
# arepurelylanguagebased.Weneedmodelsinwhichlan-
# guageisapartofan
# integratedunderstandingsystem
# (IUS)
# forunderstandingandcommunicatingaboutthesituations
# weencounterandtheobjectsthatparticipateinthem.Rep-
# resentationsofsituationsconstituteourmodelsofourworld
# andguideourbehaviorandourinterpretationoflanguage.
# Indeed,resolvingthereferentofthepronouninaWinograd
# sentencewouldfollowfrombuildingarepresentationofthe
# situationthesentencedescribes.Inthesituationinwhicha
# trombonedoesnot˝tinasuitcase,thenaturalreasonwould
# bethatthetromboneistoobigorthesuitcasetoosmall;the
# identityofthereferentofthepronounfollowsfromrealizing
# this.Thus,solvingtheWinogradSchemachallengeisanatu-
# ralbyproductofthehumanlanguageunderstandingprocess.
# Inshort,wearguethatlanguageevolvedforcommunication
# aboutsituationsandoursystemsshouldaddressthisgoal.
# Situationscanbeconcreteandstatic,suchasonewhere
# acatisonamat,ortheymaybeeventssuchasonewhere
# aboyhitsaball.Theycanbeconceptual,socialorlegal,
# suchasonewhereacourtinvalidatesalaw.Theymayeven
# beimaginary.Theobjectsmayberealor˝ctitiousphysical
# objectsorlocations;animals,persons,groupsororganizations;
# beliefsorotherstatesofmind;orentitiessuchastheories,
# lawsorconstitutions.Herewefocusonconcretesituations,
# consideringothercasesbelow.Ourproposalbuildsonclassic
# workinlinguistics(
# 31
# ,
# 32
# ),humancognition(
# 33
# ),arti˝cial
# intelligence(
# 34
# ),andanearlyPDPmodel(
# 35
# )anddovetails
# withanemergingperspectiveincognitiveneuroscience(
# 36
# ).
# Ashumansprocesslanguage,weconstructarepresentation
# ofthesituationthelanguagedescribesfromthestreamof
# wordsandotheravailableinformation.Wordsandtheirse-
# quencingserveas
# cluestomeaning
# (
# 37
# )thatjointlyconstrain
# theunderstandingofthesituationandeachobjectparticipat-
# inginit(
# 35
# ).Considerthispassage:
# Johnspreadjamonasliceofbread.Theknifehad
# McClellandetal.:Languageunderstandinginhumansandmachines3
#
# beendippedinpoison.Johnatethebreadandsoon
# begantofeelsick.
# Wecanmakemanyinferenceshere:thatthejamwasspread
# withthepoisonedknife,thatsomeofthepoisonwastrans-
# ferredtothebread,andthatthismayhaveledtoJohn's
# sickness.Notethattheentitieshereareobjects,notwords,
# andthesituationcouldinsteadbeconveyedbyasilentmovie.
# Evidencethathumansconstructsituationrepresentations
# comesfromclassicworkbyBransfordandcolleagues(
# 33
# ,
# 38
# ).
# Thisworkdemonstratesthat(1)weunderstandandremember
# textsbetterwhenwecanrelatethestatementsinthetext
# toafamiliarsituation;(2)informationthatconveysaspects
# ofthesituationcanbeprovidedbyapictureaccompanying
# thetext;(3)thecharacteristicsoftheobjectsweremember
# dependonthesituationsinwhichtheyoccurredinatext;
# (4)werepresentinmemoryobjectsnotexplicitlymentioned
# intexts;and(5)afterhearingasentencedescribingspatial
# orconceptualrelationshipsamongobjects,weretainmem-
# oryfortheserelationshipsratherthanthelinguisticinput.
# Further,evidencefromeyemovementsshowsthatpeopleuse
# linguisticandnon-linguisticinputjointlyandimmediatelyas
# theyprocesslanguageincontext(
# 39
# ).Forexample,justafter
# hearing
# Themanwilldrink...
# participantslookatafullwine
# glassratherthananemptybeerglass(
# 40
# ).Afterhearing
# The
# mandrank
# ,theylookattheemptybeerglass.Thus,language
# understandinginvolvesrealrepresen-
# tationofthesituationbeingdescribedbylanguageinput,
# includingtheobjectsinvolvedandtheirspatialrelationships
# witheachother,usingvisualandlinguisticinputs.
# Theunderstandingsysteminthebrain.
# Fig.
# 4
# presentsade-
# pictionofourproposedintegratedunderstandingsystem.
# Our
# proposalisbothatheoryofthebrainbasisofunderstanding
# andaproposedarchitectureforfuturelanguageunderstanding
# research.
# Itislargelyconsistentwithproposalsin(
# 36
# ).First,
# wefocusonapartofthesystem,calledtheneocorticalsys-
# tem,thatissu˚cienttocombinelinguisticandnon-linguistic
# inputtounderstandtheobjectandsituationreferredtoupon
# hearingasentencecontainingtheword
# bat
# whileobserving
# acorrespondingsituationintheworld.Thissystemconsists
# oftheblueovals(correspondingtopoolsofneuronsinthe
# brain)andbluearrows(connectionsbetweenthesepools)in
# the˝gure.Onepopulationsubservesavisualrepresenta-
# tion/embeddingofthegivensituation,andanothersubserves
# anon-semanticlinguisticrepresentationcapturingthesound
# structure(phonology)ofco-occurringspokenlanguage.The
# thirdrepresentsobjectsparticipatinginthesituation,and
# thefourthrepresentstheoverallsituationitself.Withineach
# pool,andbetweeneachconnectedpairofpools,theneurons
# arereciprocallyinterconnectedvialearning-dependentpath-
# waysallowingmutualconstraintsatisfactionamongallofthe
# elementsofeachoftheembeddingtypes.Brainregionsfor
# representingvisualandlinguisticinputsarewell-established,
# andtheevidencefortheirinvolvementinamutualconstraint
# satisfactionprocessissubstantial(
# 41
# ).Herewefocusonthe
# evidenceforobjectandsituationrepresentationsinthebrain.
# Objectrepresentations.
# Abrainareanearthefrontofthetempo-
# rallobehousesneuronswhoseactivityprovidesanembedding
# capturingthepropertiesofanobjectsomeoneisconsidering
# (
# 42
# ).Damagetothisareaimpairstheabilitytonameobjects,
# tograspobjectscorrectlyinserviceoftheirintendeduse,to
# Fig.4.
# Proposedintegratedunderstandingsystem(IUS).Theblueboxcontains
# theneocorticalsystem,witheachovalforminganembedding(representation)ofa
# kindofinformation.Bluearrowsrepresentlearnedconnectionsthatallow
# theembeddingstoconstraineachother.Theredboxcontainsthemedialtemporal
# lobesystem,thoughttoprovideanetworkthatstoresanintegratedembeddingofthe
# neocorticalsystemstate.Theredarrowrepresentsfast-learningconnectionsthat
# bindtheelementsofthisembeddingtogetherforlaterreactivationanduse.Green
# arrowsconnectingtheredandblueovalssupportbidirectionalencesbetween
# thetwosystems.(A)and(B)aretwoexampleinputsdiscussedinthemaintext.
# matchobjectswiththeirnamesorthesoundsthattheymake,
# andtopairobjectsthatgotogetherwitheachother,either
# fromtheirnamesorfrompictures.Modelsthatcapturethese
# ˝ndings(
# 43
# )treatthisareaasthehiddenlayerofaninterac-
# tive,recurrentnetworkwithbidirectionalconnectionstoother
# layerscorrespondingtobrainareasthatrepresentdi˙erent
# typesofobjectpropertiesincludingtheobject'sname.Inthese
# models,aninputtoanyoftheseotherlayersactivatesthecor-
# respondingpatterninthehiddenlayer,whichinturnactivates
# thecorrespondingpatternsintheotherlayers,supporting,for
# example,theabilitytoproducethenameofanobjectfrom
# visualinput.Damage(simulatedbyremovalofneuronsinthe
# hiddenlayer)degradesthemodel'srepresentations,capturing
# thepatternsoferrorsmadebypatientswiththecondition.
# Situationrepresentations.
# Thesituationrepresentationspeci˝es
# theeventorsituationconveyedbyvisualand/orlanguage
# input.Evidencefrombehavioralstudiesindicatesthatcon-
# structionofasituationrepresentationcanoccurwithorwith-
# outlanguageinput(
# 44
# )orthroughtheconvergentin˛uence
# ofbothsourcesofinformation(
# 40
# ).Cognitiveneuroscience
# researchsupportstheideathatthesituationrepresentation
# arisesinasetofinterconnectedbrainareasprimarilylocated
# inthefrontalandparietallobes(
# 36
# ,
# 45
# ).Inrecentwork,brain
# imagingdataisusedtoanalyzethetime-varyingpatterns
# ofneuralactivitythatariseduringtheprocessingofatem-
# porallyextendedeventsequence.Theactivitypatternsthat
# McClellandetal.:Languageunderstandinginhumansandmachines4
#
# representcorrespondingeventsinasequencearelargelythe
# same,whethertheinformationaboutthesequencecomesfrom
# watchingamovie,hearingorreadinganarrativedescription,
# orrecallingthemovieafterhavingseenit(
# 46
# ,
# 47
# ).
# constraints.
# Animportantfeatureofourbrain-
# inspiredproposalistheuseofdistinctsituationandobject
# representations,andtheideathattheconstraintsonthepar-
# ticipatingobjectsaremediatedbythesituationrepresentation.
# Theadvantageofthisisthatitallowstheseconstraintsto
# besituation-speci˝c.Forexample,thedogsintheeventsde-
# scribedbythesentences
# theboyran
# to
# thedog
# and
# theboyran
# from
# thedog
# arelikelytobedi˙erent,andacomprehenderwill
# representthemdi˙erently(
# 38
# ).Ingeneral,context-sensitivity
# isbestcapturedbyamediatingrepresentationratherthan
# directassociationsamongconstituents(
# 48
# ).WhileBERT-like
# modelsmightpartiallycapturesuchconstraintsimplicitly,an
# integratedsituationrepresentationmaybemoree˙ective.
# Insummary,thebraincontainsdistinctareasthatrepresent
# eachinputmodalityandtheobjectsandsituationsconveyed
# throughthem,computingtheserepresentationsthrougha
# mutualconstraintsatisfactionprocesscombininglanguageand
# otherinputs.Emulatingthisarchitectureinmachinescould
# contributetoachievinghuman-levellanguageunderstanding.
# Whatwouldacomputationalinstantiationofoursystemlook
# like?Itislikelythatabiologicallyrealisticversionwould
# di˙erinsomewaysfromthemoste˙ectivemachineversion.
# Contemporaryattention-basedlanguagemodelscandeploy
# attentionovertenstothousandsofwordskeptintheircurrent
# systemstate,butevidencefrombrainimagingdatacollected
# duringmoviecomprehensionsuggeststhatactivationstatesin
# visual,speech,andobjectareaschangerapidlyaseventsunfold,
# whilethebrainstatetendstobemoreconstant,changingonly
# ateventboundariesinbrainareasassociatedwithsituation
# representations(
# 47
# ).Inhumans,spanninglongertemporal
# windows,includingmulti-eventnarratives,appearstorequire
# thecomplementarylearningsystemweconsidernext.
# ComplementaryLearningSystems.
# Learningplaysacrucial
# roleinunderstanding.Theknowledgeintheconnection
# weightsintheneuralnetworkswehavedescribedisacquired
# throughtheaccumulationofverysmalladjustmentsbasedon
# eachexperience.Theconnectionweightsgraduallybecome
# sensitivetosubtlehigher-orderstatisticalrelationships,taking
# moreandmorecontextintoaccountaslearningcontinues(
# 49
# ),
# andexhibitingsensitivitybothtogeneralandrecurringspeci˝c
# information(e.g.,namesofclosefriendsandfamouspeople).
# Inourproposedarchitecture,thisgradualprocessoccursin
# allthepathwaysrepresentedbythebluearrowsinFig.
# 4
# ,just
# asitdoesinthearti˝cialneurallanguagemodelsconsidered
# above.However,thislearningmechanismisnotwellsuitedto
# acquiringnewinformationrapidly,andattemptingtolearn
# speci˝cnewinformationquicklybyfocusedrepetitionleads
# tocatastrophicinterferencewithwhatisalreadyknown(
# 50
# ).
# Yet,humanscanoftenrelyoninformationpresentedjust
# onceatanarbitrarytimeinthepasttoinformourcurrent
# understanding.ReturningtothebeerJohnleftinthecooler,
# toanticipatethatJohnwillnot˝ndthebeerwhenheopens
# thecooleragain,wemustrelyoninformationacquiredwhen
# we˝rstheardaboutthebeerbeingstolen.Suchsituations
# areubiquitous,andalearningsystemmustbeabletoexploit
# suchinformation,butBERTandtheothermodelsdescribed
# previouslyarelimitedinthisway.Thoughsomemodelshold
# longwordsequencesinanactivestate,whenonetextis
# replacedwithanother,onlythesmallconnectionadjustments
# describedaboveremain,leavingthesesystemswithoutaccess
# tothespeci˝csofthepriorinformation.
# Thehumanbraincontainsasystemthataddressesthis
# limitation.Considerasituationinwhichsomeoneseesapre-
# viouslyunfamiliarobjectandhearsaspokenstatementabout
# it,asillustratedinFig.
# 4
# B.Thevisualinputprovidesone
# sourceofinformationabouttheobject(apreviouslyunfamiliar
# animal),whilethelinguisticinputprovidesitsname.Humans
# showrobustlearningafterjusttwobriefexposurestosuch
# pairings(
# 51
# ).Thisformoflearningdependsonthehippocam-
# pusandadjacentareasinthemedialtemporallobes(MTL)
# ofthebrain(
# 51
# ).WhiledetailsoftheroleoftheMTLin
# learningandmemorycontinuetobedebated(
# 52
# ,
# 53
# ),thereis
# consensusthattheMTLiscrucialfortheinitialformationof
# newmemories,includingmemoriesforspeci˝ceventsandtheir
# constituentobjectsandsituations,whilegeneralknowledge,
# theabilitytounderstandlanguage,andpreviouslyacquired
# skillsareuna˙ectedbyMTLdamage.
# TheevidencefromMTLdamagesuggeststhereisafast
# learningsystemintheMTL.Accordingtocomplementary
# learningsystemstheory(CLST)(
# 54
#
# 56
# )thissystem(shown
# inredinFig.
# 4
# )providesanintegratedrepresentationofthe
# understandingsystemstate,andemploysmodi˝ableconnec-
# tionswithintheMTL(redarrow)thatcanchangerapidlyto
# supportnewlearningbasedonasingleexperience.Thegreen
# arrowsrepresentconnectionsthatcarryinformationbetween
# theneocortical(blue)andMTL(red)systemssothesystems
# canin˛uenceeachother.
# Letusconsiderhow,accordingtoCLST,ahumancanlearn
# aboutthenumbat(seeFig.
# 4
# B)fromanexperienceseeing
# itandhearingasentenceaboutit(
# 56
# ).Theinputtothe
# MTListhoughttobeanembeddingthatcaptures(i.e.,can
# beusedtoreconstruct)thepatternsintheneocorticalareas
# thatarisefromtheexperience.NetworkswithintheMTL(not
# shown)maptheMTLinputrepresentationtoasparserone
# deepinsidetheMTL,maximizingdistinctnessandminimizing
# interferenceamongexperiences(
# 54
# ).Largeconnectionweight
# changeswithintheMTLassociatetheelementsofthesparse
# representationwitheachotherandwiththeMTLinputrepre-
# sentation.Whenthepersonhearstheword
# numbat
# inalater
# situation,connectionstotheMTLfromtheneocortexactivate
# neuronsintheMTLinputrepresentation.Theweightchanges
# thatoccurredonpriorexposuresupportthereconstruction
# ofthecompleteMTLrepresentation,andreturnconnections
# totheneocortexthensupportapproximatereconstructionof
# thevisual,speech,objectandsituationrepresentationsformed
# duringtheinitialexposuretothenumbat.Theserepresenta-
# tionsaretheexplicitmemoryforthepriorexperience,allowing
# thecorticalnetworktousewhatitlearnedfromoneprior
# exposuretocontributetounderstandingthenewsituation.
# Integratinginformationintotheneocortex.
# Howcanknowledgeini-
# tiallydependentontheMTLbeintegratedintotheneocor-
# tex?AccordingtoCLST(
# 55
# ),theneocortexlearnsgradually
# throughinterleavedpresentationsofnewandfamiliaritems;
# thisprocessavoidsinterferenceofnewitemswithwhatisal-
# readyknown.Interleavedlearningcanoccurthroughongoing
# experience,aswouldhappenif,forexample,weacquireapet
# numbatthatwethenseeeveryday,whilecontinuingtohave
# McClellandetal.:Languageunderstandinginhumansandmachines5
# otherexperiences.Interleavingmayalsooccurduringrest
# orsleepthroughreactivationandreplayofpatternsstored
# intheMTL:Indeed,spontaneousreplayofshortsnippetsof
# previouslyexperiencedepisodesoccurswithintheMTLduring
# sleepandbetweenbehavioralepisodes(see(
# 56
# )forreview).
# Insummary,thehumanbraincontainscomplementary
# learningsystemsthatsupportthesimultaneoususeofmany
# sourcesofinformationasweseektounderstandanexperienced
# situation.Oneofthesesystemsacquiresanintegratedsystem
# ofknowledgegraduallythroughinterleavedlearning,includ-
# ingourknowledgeofthemeaningsofwords,theproperties
# offrequently-encounteredobjects,andthecharacteristicsof
# familiarsituations.Theothercomplementsthissystemto
# allowinformationfromspeci˝cexperiencestobebroughtto
# bearontheinterpretationofacurrentsituation.
# TowardanArIntegratedUnderstandingSystem
# Hereweconsidercurrentdeeplearningresearchthatistaking
# stepsconsistentwithourIUSproposal,andpointtowardfu-
# turedirectionsthatwillbeneededtoachieveatrulyintegrated
# andfullyfunctionalunderstandingsystem.Webeginwithin
# thecontextoflanguagegroundedwithinconcretevisualand
# physicalsituations,thenconsidertheroleofmemory,and
# ˝nallyturntotheextensionoftheapproachtoaddressunder-
# standingofmoreabstractobjects,situations,andrelations.
# Mappingvisionandlanguagetorepresentationsofobjects.
# Howmightamodellearnaboutsituationsthatcanoccur
# intheworld?Theneedforanarti˝cialsystemoflanguage
# understandingtobegroundedintheexternalworldhaslong
# beendiscussed.AnearlyexampleisWinograd'sSHRDLU
# system(
# 57
# ),whichproducedandrespondedtolanguageabout
# asimulatedphysicalworld.Deeplearninghasenabled
# joint
# ,
# end-to-end
# trainingofperceptualinputandlanguage(i.e.,in
# asinglesynchronousoptimizationprocess).Recentadvances
# withsuchmodelshavegreatlyimprovedperformance,resulting
# inapplicationstransforminguserexperiences.Whenpresented
# withaphotograph,networkscannowanswerquestionssuch
# as
# whatisthemanholding?
# or
# whatcoloristhewoman's
# shirt?
# (
# 58
# ),demonstratinganabilitytocombineinformation
# fromvisionandlanguagetounderstandaclassofsituations.
# Averyrecentmodel(
# 59
# )explicitlyrepresentstheobjectsin
# ascene,theirproperties,andtheirrelationstootherobjectsin
# adesigned
# scenegraph
# withslotsforobjects,theirproperties,
# andrelations.Itencodesquestionsasaseriesofinstructions
# to˝ndatargetobjectorrelationbysearchingthegraphto
# answeraquery.Forexample,thequestion
# whatistheobject
# besidetheyellowbowl?
# canbeansweredby˝ndingtheyellow
# bowl,˝ndinganobjectlinkedtoitwiththe`beside'relation,
# andthenreadingoutthisobject'sidentity.Theapproach
# advancesthestateoftheart,thoughalargegaprelative
# tohumansremains.Themodelsharesimportantproperties
# withourproposalinthatitexplicitlytreatslanguageinput
# asqueryingthemodel'srepresentationoftheobjectsinthe
# scene,andtheirconceptualproperties.Anaturalextension
# consistentwithIUSwouldbetobuildupscenerepresentations
# usingacombinationofvisualinputandlanguage,allowing
# texttoenrichtherepresentationsofobjectsandrelations.
# Aquestionthisworkraisesiswhethertobuildstructured
# representationsintoone'smodel.Thisisadvocatedin(
# 59
# ),
# butnaturalstructureexhibits˛exibleembeddingrelationships
# andisoftenonlyapproximatelycharacterizedbyexplicittax-
# onomies,motivatinguseofemergentconnection-basedrather
# thanhard-codedrepresentationalstructures(
# 60
# ).Achallenge,
# then,istoachievecomparableperformancewithmodelsin
# whichtheseconcept-basedobjectandrelationalrepresenta-
# tionsemergethroughlearning.
# Embodiedmodelsforlanguageunderstanding.
# Beyondthe
# integrationofvisionandlanguage,asillustratedinFig.
# 4
# ,we
# seeprogresscomingfromanevenfullerintegrationofmany
# additionalinformationsources.Everysourceprovidesabasis
# fordistinctlearningobjectivesandenablesinformationthat
# issalientinonesourcetobootstraplearningandinferencein
# theother.Importantadditionalsourcesofinformationinclude
# non-languagesound,touchandforce-sensing,andinformation
# aboutone'sownactions.
# Incorporatingadditionalinformationsourceswillallowan
# IUStogobeyondansweringquestionsaboutstaticimages.
# Sinceimagedatahasnotemporalaspect,suchmodelslack
# experienceofeventsorprocesses.Whilemodelsthatjointly
# processvideoandlanguage(
# 61
# )mayacquiresomesensitiv-
# itytoeventstructureandcommonplacecausalrelationships,
# thesesystemsdonotmakechoicesa˙ectingtheworldthey
# observe.Ultimately,anabilitytolinkone'sactionstotheir
# consequencesasoneintervenesintheobserved˛owofevents
# andinteractswithotheragentsshouldprovidethestrongest
# basisforacquiringnotionsofcauseande˙ect,ofagency,and
# ofselfandothers.
# Theseconsiderationsmotivaterecentworkonagent-
# basedlanguagelearninginsimulatedinteractive3Denviron-
# ments(
# 62
#
# 65
# ).In(
# 66
# ),anagentwastrainedtoidentify,lift,
# carryandplaceobjectsrelativetootherobjectsinavirtual
# room,asspeci˝edbysimpli˝edlanguageinstructions.Ateach
# timestep,theagentreceiveda˝rst-personvisualobservation
# (pixel-basedimage)thatitprocessedtoproducearepresenta-
# tionofthescene.Thiswasconcatenatedtothe˝nalstateof
# anLSTMthatprocessedtheinstruction,thenpassedtoan
# integrativeLSTMwhoseoutputwasusedtoselectamotor
# action.Theagentgraduallylearnedtofollowinstructionsof
# theform
# ˝ndapencil
# ,
# liftupabasketball
# and
# puttheteddy
# bearonthebed
# ,encompassing50objects,andrequiringup
# to
# 70
# actionstepstocomplete.Suchinstructionsrequirethe
# constructionofrepresentationsbasedonlanguagestimulithat
# enabletheidenti˝cationofobjectsandrelationsacrossspace
# andtime,andtheintegrationofthisinformationtoinformmo-
# torbehaviors.Importantly,withoutbuildinginexplicitobject
# representations,thesystemsupportedtheinterpretationof
# novelinstructions.Forinstance,anagenttrainedtoliftaset
# of20objectsintheenvironment,butonlytrainedtoput10of
# thoseinaspeci˝clocationcouldplacetheremainingobjects
# inthesamelocationoncommandwithover90%accuracy.
# Neuralmodelsoftenfailtoexhibitsystematicgeneraliza-
# tion,leadingsometoproposethatmorestructureshouldbe
# builtin(
# 67
# ).Whiletheagent'slevelofsystematicitydoes
# notreachhumanlevels,thisworksuggeststhatgroundinglan-
# guagelearningcanhelpsupportsystematicity
# withoutbuilding
# itin
# .Critically,theagent'ssystematicitywascontingenton
# theego-centric,multimodalandtemporally-extendedexpe-
# rienceoftheagent.Onthesamesetofgeneralizationtests,
# bothanalternativeagentwitha˝xedperspectiveona2Dgrid
# worldandastaticneuralnetworkclassi˝erthatreceivedonly
# individualstillimagestimuliexhibitedsigni˝cantlyworsegen-
# McClellandetal.:Languageunderstandinginhumansandmachines6
#
# Fig.5.
# Left:the(allocentric)agentperspectiveina2Dgrid-world.Thetextindicates
# thelanguageinstruction,requiringtheagent(whitestripedcell)tovisitoneofthe
# redandmoveittothewhitesquare.Right:theperspectiveofthe
# situatedagent,addressinganequivalenttasktotheoneposedinthegridworld.
# eralizationthatafullysituatedagent(Fig.
# 5
# ).Thisunderlines
# howa˙ordingneuralnetworksaccesstorich,multi-modal
# interactiveenvironmentscanstimulatethedevelopmentof
# capacitiesthatareessentialforlanguagelearning.
# Despitethesepromisingsigns,achievingfullyhumanlevels
# ofgeneralizationremainsanimportantchallenge.Wepropose
# thatincorporatinganMTL-likefastlearningsystemwillhelp
# addressthisbyallowingnewwordstobelinkedtothecorre-
# spondingobjectfromjustasingleepisodesupportinguseof
# thewordtorefertothereferentinothersituations.
# Anarfastlearningsystem.
# Whatmightafastlearning
# systeminanimplementationofanintegratedunderstanding
# systemlooklike?Thememorysysteminthedi˙erentiable
# neuralcomputer(DNC)(
# 68
# )isonepossibility.Thesesystems
# storeembeddingsderivedfrompastepisodesinslotsthat
# couldstoreIntegratedSystemStaterepresentationslikethose
# weattributetothehumanMTL.Alternatively,theycould
# storetheentireensembleofstatesacrossthevisual,speech,
# object,andsituationrepresentations.Thoughwedonot
# believethebrainhasaseparateslotforeachmemory,itcan
# beusefultomodelitasthoughitdoes(
# 56
# ),andarti˝cial
# systemswithinde˝nitecapacitycouldexceedhumanabilities
# inthisregard.Howmighttheretrievalofrelevantinformation
# workinsuchasystem?TheDNCemploysaqueryingsystem
# similartotheoneinBERTandtoproposalsinthehuman
# memoryliterature,wherebytherepresentationretrievedfrom
# theMTLisweightedbythedegreeofmatchbetweenaquery
# (whichwewouldtreatascomingfromtheneocortex)andeach
# vectorstoredinmemory.Closematchesarefavoredinthis
# computation(
# 69
# ),sothatwhenthereisauniquematch(such
# asasinglememorycontainingaonceseenwordlike
# numbat
# ),
# thecorrespondingobjectandsituationrepresentationcould
# beretrieved.Retrievalcouldbebasedonacombinationof
# contextanditeminformation,similartohumanmemory(
# 70
# ).
# Workingoutthedetailsofsuchasystempresentsanexciting
# researchdirectionforthefuture.
# Beyondconcretesituations.
# Ourdiscussionhasfocusedpri-
# marilyonconcretesituations.However,languageallowsusto
# discussabstractideasandsituations,wheregroundinginthe
# physicalworldcanbeveryindirectandourlearningabout
# itcomesprimarilyfromlanguage-basedmaterials.Consider,
# forexample,anunderstandingof
# Brexit
# .Concreteevents
# involvingactualpeoplehaveoccurred,buttheissuesandques-
# tionsunderconsiderationcanonlybecommunicatedthrough
# language.Whatisthewayforwardtowarddevelopingmodels
# thatcanunderstandsuchacomplexsituation?
# Languagemayhaveevolvedinparttosupporttransmission
# ofcomplex,hierarchicalknowledgeabouttools(
# 71
# ).How-
# ever,utterancesalsohadtosupportabstractionandcomplex
# dependenciesbetweenconcreteobjects,aswellassocialre-
# lationshipsbetweenspeakers.Wordsthemselvesprovideda
# newabstractsubstrateforcharacterizingotherwords(
# 72
# ).
# Wordembeddingsareoneimplementationofthissubstrate:
# theycancharacterizeabstractwordslike
# justice
# and
# represents
# withoutdirectlygroundingthem.Inhumans,encyclopedic
# knowledgegroundedinsuchrepresentationscanbeacquired
# inanMTL-dependentwayfromreadinganencyclopediaarti-
# clejustonce.Formachines,formingintegratedsystemstate
# representationscapturingthecontentandusingaDNC-like
# systemfortheirstorageandretrievalmightprovideastarting
# placeforenablingsuchknowledgetobeacquiredandused
# e˙ectively.
# Thatsaid,wordsareutteredinrealworldcontextsandthere
# isacontinuumbetweengroundingandlanguage-basedlinking
# fordi˙erentwordsanddi˙erentusesofwords.Forexample,
# career
# isnotonlylinkedtootherabstractwordslike
# work
# and
# specialization
# butalsotomoregroundedconceptssuchas
# path
# anditsextendedmetaphoricalusefordiscussingthemeansto
# achievegoals(
# 72
# ).Embodied,simulation-basedapproaches
# tomeaning(
# 73
# ,
# 74
# )buildonthisobservationtobridgefrom
# concretetoabstractsituationsviametaphor.Theyposit
# thatunderstandingwordslike
# grasp
# isdirectlylinkedtoneural
# representationsoftheactionofgrabbingandthatthiscircuitry
# isrecruitedforunderstandingthewordincontextssuchas
# graspinganidea
# .Weconsidersituatedagentsasacritical
# catalystforlearningabouthowtorepresentandcompose
# conceptspertainingtospatial,physicalandotherperceptually
# immediateyprovidingagroundededi˝ce
# thatcanconnecttoboththelowlevelbraincircuitryformotor
# actionandtorepresentationsderivedprimarilyfromlanguage.
# Conclusion.
# Languagedoesnotstandalone.Theintegrated
# understandingsysteminthebrainconnectslanguagetorep-
# resentationsofobjectsandsituationsandenhanceslanguage
# understandingbyexploitingthefullrangeofourmulti-sensory
# experienceoftheworld,ourrepresentationsofourmotor
# actions,andourmemoryofprevioussituations.Wehavear-
# guedthatthenextgenerationlanguageunderstandingsystem
# shouldemulatethissysteminthebrainandwehavesketched
# someaspectsoftheformsuchasystemmighttake.While
# wehaveemphasizedunderstandingofconcretesituations,we
# havearguedthatunderstandingmoreabstractlanguagebuilds
# uponthisconcretefoundation,pointingtowardthepossibility
# thatitmaysomedaybepossibletobuildarti˝cialsystemsthat
# understandabstractsituationsfarbeyondtheconcreteand
# thehere-and-now.Insum,wehaveproposedthatmodeling
# theintegratedunderstandingsysteminthebrainwilltakeus
# closertocapturinghuman-levellanguageunderstandingand
# intelligence.
# ACKNOWLEDGMENTS.
# Thisarticlegrewoutofaworkshop
# organizedbyHSat
# MeaninginContext3
# ,StanfordUniversity,
# September2017.WethankChrisPottsfordiscussion.HSwas
# supportedbyERCAdvancedGrant#740516.
# McClellandetal.:Languageunderstandinginhumansandmachines7
# 1.
# WuY,etal.(2016)Google'sneuralmachinetranslationsystem:Bridgingthegapbetween
# humanandmachinetranslation.
# -
# .
# 2.
# RosenblattF(1961)
# Principlesofneurodynamics.perceptronsandthetheoryofbrainmech-
# anisms
# .(SpartanBooks,CornellUniversity,Ithaca,NewYork).
# 3.
# RumelhartDE,McClellandJL,thePDPresearchgroup(1986)
# ParallelDistributedProcess-
# ing.ExplorationsintheMicrostructureofCognition.Volume1:Foundations
# .(TheMITPress,
# Cambridge,MA).
# 4.
# RumelhartDE,McClellandJL(1986)OnlearningthepasttensesofEnglishverbsin
# Parallel
# DistributedProcessing.ExplorationsintheMicrostructureofCognition.Volume2:Psycho-
# logicalandBiologicalModels
# ,eds.McClellandJL,RumelhartDE,thePDPResearchGroup.
# (MITPress),pp.216Œ271.
# 5.
# RumelhartDE(1977)Towardaninteractivemodelofreadingin
# Attention&PerformanceVI
# ,
# ed.DornicS.(LEA,Hillsdale,NJ),pp.573Œ603.
# 6.
# McClellandJL,RumelhartDE(1981)Aninteractiveactivationmodelofcontexteffectsinletter
# perception:I.anaccountofbasic.
# Psychologicalreview
# 88(5):375.
# 7.
# JJ(1982)Neuralnetworksandphysicalsystemswithemergentcollectivecomputa-
# tionalabilities.
# Proceedingsofthenationalacademyofsciences
# 79(8):2554Œ2558.
# 8.
# AckleyDH,HintonGE,SejnowskiTJ(1985)Alearningalgorithmforboltzmannmachines.
# Cognitivescience
# 9(1):147Œ169.
# 9.
# ElmanJL(1990)Findingstructureintime.
# CognitiveScience
# 14:179Œ211.
# 10.
# GoldEM(1967)Languageinthelimit.
# Informationandcontrol
# 10(5):447Œ474.
# 11.
# ElmanJL(1991)Distributedrepresentations,simplerecurrentnetworks,andgrammatical
# structure.
# Mach.Learn.
# 7(2/3):195Œ225.
# 12.
# HochreiterS,BengioY,FrasconiP,SchmidhuberJ(2001)Gradientwinrecurrentnets:the
# oflearninglong-termdependenciesin
# AFieldGuidetoDynamicalRecurrentNeural
# Networks
# ,eds.KremerSC,KolenJF.(IEEEPress).
# 13.
# HochreiterS,SchmidhuberJ(1997)Longshort-termmemory.
# Neuralcomputation
# 9(8):1735Œ1780.
# 14.
# CollobertR,etal.(2011)Naturallanguageprocessing(almost)fromscratch.
# Journalof
# MachineLearningResearch
# 12(Aug):2493Œ2537.
# 15.
# MikolovT,SutskeverI,ChenK,CorradoGS,DeanJ(2013)Distributedrepresentationsof
# wordsandphrasesandtheircompositionalityin
# NeuralInformationProcessingSystems
# .pp.
# 3111Œ3119.
# 16.
# SimpsonGB(1981)Meaningdominanceandsemanticcontextintheprocessingoflexical
# ambiguity.
# Journalofverballearningandverbalbehavior
# 20(1):120Œ136.
# 17.
# RudolphM,RuizF,BleiD(2017)Structuredembeddingmodelsforgroupeddatain
# Advances
# inNeuralInformationProcessingSystems
# .
# 18.
# PetersME,etal.(2018)Deepcontextualizedwordrepresentations.
# CoRR
# abs/1802.05365.
# 19.
# VaswaniA,etal.(2017)Attentionisallyouneedin
# AdvancesinNeuralInformationProcess-
# ingSystems30
# .(CurranAssociates,Inc.),pp.5998Œ6008.
# 20.
# DevlinJ,ChangMW,LeeK,ToutanovaK(2018)BERT:Pre-trainingofDeepBidirectional
# TransformersforLanguageUnderstanding.
# ArXive-prints
# .
# 21.
# YangZ,etal.(2019)Xlnet:Generalizedautoregressivepretrainingforlanguageunderstand-
# ing.
# CoRR
# abs/1906.08237.
# 22.
# DehghaniM,GouwsS,VinyalsO,UszkoreitJ,KaiserL(2018)Universaltransformers.
# CoRR
# abs/1807.03819.
# 23.
# UszkoreitJ(2017)Transformer:Anovelneuralnetworkarchitectureforlanguageunderstand-
# ing,https://ai.googleblog.com/2017/08/transformer-novel-neural-network.html.
# 24.
# RadfordA,NarasimhanK,SalimansT,SutskeverI(2018)Improvinglanguageunderstanding
# bygenerativepre-training.OpenAIPreprint.
# 25.
# DevlinJ,ChangMW,LeeK,ToutanovaK(2018)Bert:Pre-trainingofdeepbidirectional
# transformersforlanguageunderstanding.
# arXivpreprintarXiv:1810.04805
# .
# 26.
# WangA,etal.(2018)Glue:Amulti-taskbenchmarkandanalysisplatformfornaturallan-
# guageunderstanding.
# arXivpreprintarXiv:1804.07461
# .
# 27.
# WangA,etal.(2019)Superglue:Astickierbenchmarkforgeneral-purposelanguageunder-
# standingsystems.
# arXivpreprintarXiv:1905.00537
# .
# 28.
# LevesqueH,DavisE,MorgensternL(2012)Thewinogradschemachallengein
# Thirteenth
# InternationalConferenceonthePrinciplesofKnowledgeRepresentationandReasoning
# .
# 29.
# RaffelC,ShazeerN,RobertsA,,etal.(2019)Exploringthelimitsoftransferlearningwitha
# text-to-texttransformer.
# arXivpreprintarXiv:1910.10683
# .
# 30.
# JiaR,LiangP(2017)Adversarialexamplesforevaluatingreadingcomprehensionsystemsin
# Proceedingsofthe2017ConferenceonEmpiricalMethodsinNaturalLanguageProcessing
# .
# (AssociationforComputationalLinguistics),pp.2021Œ2031.
# 31.
# LakoffG(1987)
# Women,Fire,andDangerousThings
# .(TheUniversityofChicagoPress,
# Chicago).
# 32.
# LangackerRW(1987)
# Foundationsofcognitivegrammar:Theoreticalprerequisites
# .(Stan-
# forduniversitypress)Vol.1.
# 33.
# BransfordJD,JohnsonMK(1972)Contextualprerequisitesforunderstanding:Somein-
# vestigationsofcomprehensionandrecall.
# Journalofverballearningandverbalbehavior
# 11(6):717Œ726.
# 34.
# SchankRC(1983)
# Dynamicmemory:Atheoryofremindingandlearningincomputersand
# people
# .(CambridgeUniversityPress).
# 35.
# JohnMFS,McClellandJL(1990)Learningandapplyingcontextualconstraintsinsentence
# comprehension.
# ArIntelligence
# 46(1):217Œ257.
# 36.
# HassonU,EgidiG,MarelliM,WillemsRM(2018)Groundingtheneurobiologyoflanguage
# inprinciples:Thenecessityofnon-language-centricexplanationsforlanguagecompre-
# hension.
# Cognition
# 180:135Œ157.
# 37.
# RumelhartDE(1979)Someproblemswiththenotionthatwordshaveliteralmeaningsin
# Metaphorandthought
# ,ed.OrtonyA.(CambridgeUniv.Press,Cambridge,UK),pp.71Œ82.
# 38.
# BarclayJ,BransfordJD,FranksJJ,McCarrellNS,NitschK(1974)Comprehensionandse-
# manticxibility.
# JournalofVerbalLearningandVerbalBehavior
# 13(4):471Œ481.
# 39.
# TanenhausMK,Spivey-KnowltonMJ,EberhardKM,SedivyJC(1995)Integrationofvisual
# andlinguisticinformationinspokenlanguagecomprehension.
# Science
# pp.1632Œ1634.
# 40.
# AltmannGT,KamideY(2007)Thereal-timemediationofvisualattentionbylanguageand
# worldknowledge:Linkinganticipatory(andother)eyemovementstolinguisticprocessing.
# JournalofMemoryandLanguage
# 57(4):502Œ518.
# 41.
# McClellandJL,MirmanD,BolgerDJ,KhaitanP(2014)Interactiveactivationandmutualcon-
# straintsatisfactioninperceptionandcognition.
# Cognitivescience
# 38(6):1139Œ1189.
# 42.
# PattersonK,NestorPJ,RogersTT(2007)Wheredoyouknowwhatyouknow?therepresen-
# tationofsemanticknowledgeinthehumanbrain.
# NatureReviewsNeuroscience
# 8(12):976.
# 43.
# RogersTT,etal.(2004)Structureanddeteriorationofsemanticmemory:aneuropsycholog-
# icalandcomputationalinvestigation.
# Psychologicalreview
# 111(1):205Œ235.
# 44.
# ZwaanRA,RadvanskyGA(1998)Situationmodelsinlanguagecomprehensionandmemory.
# Psychologicalbulletin
# 123(2):162Œ185.
# 45.
# RanganathC,RitcheyM(2012)Twocorticalsystemsformemory-guidedbehaviour.
# Nature
# ReviewsNeuroscience
# 13:713.ReviewArticle.
# 46.
# ZadboodA,ChenJ,LeongY,NormanK,HassonU(2017)Howwetransmitmemoriesto
# otherbrains:Constructingsharedneuralrepresentationsviacommunication.
# CerebralCor-
# tex
# 27(10):4988Œ5000.
# 47.
# BaldassanoC,etal.(2017)Discoveringeventstructureincontinuousnarrativeperception
# andmemory.
# Neuron
# 95(3):709Œ721.
# 48.
# HintonGE(1981)Implementingsemanticnetworksinparallelhardwarein
# ParallelModelsof
# AssociativeMemory
# ,eds.HintonGE,AndersonJA.(Erlbaum),pp.161Œ187.
# 49.
# CleeremansA,McClellandJL(1991)Learningthestructureofeventsequences.
# Journalof
# ExperimentalPsychology:General
# 120(3):235.
# 50.
# McCloskeyM,CohenNJ(1989)Catastrophicinterferenceinconnectionistnetworks:The
# sequentiallearningproblemin
# Psychologyoflearningandmotivation
# .(Elsevier)Vol.24,pp.
# 109Œ165.
# 51.
# WarrenDE,DuffMC(2019)Fastmappers,slowlearners:Wordlearningwithouthippocam-
# pusisslowandsparseirrespectiveofmethodology.
# Cognitiveneuroscience
# pp.1Œ3.
# 52.
# SquireLR(1992)Memoryandthehippocampus:asynthesisfromwithrats,mon-
# keys,andhumans.
# Psychologicalreview
# 99(2):195.
# 53.
# YonelinasA,RanganathC,EkstromA,WiltgenB(2019)Acontextualbindingtheoryof
# episodicmemory:systemsconsolidationreconsidered.
# NatureReviewsNeuroscience
# .
# 54.
# MarrD(1971)Simplememory:atheoryforarchicortex.
# PhilosophicalTransactionsofthe
# RoyalSocietyofLondonB:BiologicalSciences
# 262(841):23Œ81.
# 55.
# McClellandJL,McNaughtonBL,O'ReillyRC(1995)Whytherearecomplementarylearning
# systemsinthehippocampusandneocortex:Insightsfromthesuccessesandfailuresof
# connectionistmodelsoflearningandmemory.
# PsychologicalReview
# 102(3):419Œ457.
# 56.
# KumaranD,HassabisD,McClellandJL(2016)Whatlearningsystemsdointelligentagents
# need?Complementarylearningsystemstheoryupdated.
# TrendsinCognitiveSciences
# 20(7):512Œ534.
# 57.
# WinogradT(1972)Understandingnaturallanguage.
# Cognitivepsychology
# 3(1):1Œ191.
# 58.
# MacLeodH,BennettCL,MorrisMR,CutrellE(2017)Understandingblindpeople'sexperi-
# enceswithcomputer-generatedcaptionsofsocialmediaimagesin
# Proceedingsofthe2017
# CHIConferenceonHumanFactorsinComputingSystems
# .(ACM),pp.5988Œ5999.
# 59.
# HudsonDA,ManningCD(2019)Learningbyabstraction:Theneuralstatemachine.
# arXiv
# preprintarXiv:1907.03950
# .
# 60.
# RumelhartDE,SmolenskyP,McClellandJL,HintonG(1986)Pdpmodelsofschemataand
# sequentialthoughtprocessesinpdpmodels.
# Paralleldistributedprocessing:Explorationsin
# themicrostructureofcognition
# 2:3Œ57.
# 61.
# YuH,WangJ,HuangZ,YangY,XuW(2016)Videoparagraphcaptioningusinghierarchical
# recurrentneuralnetworksin
# ProceedingsoftheIEEEconferenceoncomputervisionand
# patternrecognition
# .pp.4584Œ4593.
# 62.
# HermannKM,etal.(2017)Groundedlanguagelearninginasimulated3dworld.
# arXiv
# preprintarXiv:1706.06551
# .
# 63.
# DasR,ZaheerM,ReddyS,McCallumA(2017)Questionansweringonknowledgebases
# andtextusinguniversalschemaandmemorynetworksin
# Proceedingsofthe55thAnnual
# MeetingoftheAssociationforComputationalLinguistic
# .pp.358Œ365.
# 64.
# ChaplotDS,SathyendraKM,PasumarthiRK,RajagopalD,SalakhutdinovR(2017)
# Gated-attentionarchitecturesfortask-orientedlanguagegrounding.
# arXivpreprint
# arXiv:1706.07230
# .
# 65.
# OhJ,SinghS,LeeH,KohliP(2017)Zero-shottaskgeneralizationwithmulti-taskdeeprein-
# forcementlearningin
# Proceedingsofthe34thInternationalConferenceonMachineLearning-
# Volume70
# .(JMLR.org),pp.2661Œ2670.
# 66.
# HillF,etal.(2019)Emergentsystematicgeneralizationinasituatedagent.
# arXivpreprint
# arXiv:1910.00571
# .
# 67.
# LakeBM,SalakhutdinovR,TenenbaumJB(2015)Human-levelconceptlearningthrough
# probabilisticprograminduction.
# Science
# 350(6266):1332Œ1338.
# 68.
# GravesA,etal.(2016)Hybridcomputingusinganeuralnetworkwithdynamicexternalmem-
# ory.
# Nature
# 538(7626):471Œ476.
# 69.
# HintzmanDL(1984)Minerva2:Asimulationmodelofhumanmemory.
# BehaviorResearch
# Methods,Instruments,&Computers
# 16(2):96Œ101.
# 70.
# PolynSM,NormanKA,KahanaMJ(2009)Acontextmaintenanceandretrievalmodelof
# organizationalprocessesinfreerecall.
# Psychologicalreview
# 116(1):129.
# 71.
# StoutD,ChaminadeT(2012)Stonetools,languageandthebraininhumanevolution.
# Philos
# TransRSocLondBBiolSci
# 367(1585):75Œ87.
# 72.
# BrysonJ(2008)Embodimentvs.memetics.
# MindandSociety
# 7(1):77Œ94.
# 73.
# LakoffG,JohnsonM(1980)
# MetaphorsWeLiveBy
# .(UniversityofChicago,Chicago,IL).
# 74.
# FeldmanJ,NarayananS(2004)Embodiedmeaninginaneuraltheoryoflanguage.
# Brain
# andLanguage
# 89:385Œ392.
# McClellandetal.:Languageunderstandinginhumansandmachines8

# %% [markdown]
# # Pdfminer <3
# **attention!** install `pdfminer.six`
# ```
# pip install pdfminer.six
# ```

# %%
from pdfminer.high_level import extract_text
text = extract_text(os.path.join(sample_pdf_dir, '2019.pdf'))
print(text)
# Out:
# 9
# 1
# 0
# 2
#
# c
# e
# D
#
# 2
# 1
#
#
# ]
# L
# C
# .
# s
# c
# [
#
#
# 1
# v
# 7
# 7
# 8
# 5
# 0
# .
# 2
# 1
# 9
# 1
# :
# v
# i
# X
# r
# a
#
# Extending Machine Language Models toward
# Human-Level Language Understanding
#
# James L. McClellanda,b,2, Felix Hillb,2, Maja Rudolphc,2, Jason Baldridged,1,2, and Hinrich Schützee,1,2
#
# aStanford University, Stanford, CA 94305, USA; bDeepMind, London N1C 4AG, UK; cBosch Center for Artiﬁcial Intelligence, Renningen, 71272, Germany; dGoogle Research,
# Austin, TX 78701, USA; eLMU Munich, Munich, 80538, Germany
#
# This manuscript was compiled on December 13, 2019
#
# Language is central to human intelligence. We review recent break-
# throughs in machine language processing and consider what re-
# mains to be achieved. Recent approaches rely on domain general
# principles of learning and representation captured in artiﬁcial neu-
# ral networks. Most current models, however, focus too closely on
# In humans, language is part of a larger system for
# language itself.
# acquiring, representing, and communicating about objects and sit-
# uations in the physical and social world, and future machine lan-
# guage models should emulate such a system. We describe exist-
# ing machine models linking language to concrete situations, and
# point toward extensions to address more abstract cases. Human
# language processing exploits complementary learning systems, in-
# cluding a deep neural network-like learning system that learns grad-
# ually as machine systems do, as well as a fast-learning system that
# supports learning new information quickly. Adding such a system to
# machine language models will be an important further step toward
# truly human-like language understanding.
#
# Language Understanding | Natural Language Processing | Situation
#
# Models | Machine Language Models | Brain System for Understanding
#
# Many of the most impressive recent successes of machine in-
# telligence have appeared in the domain of language. Machines
# can now better identify the words we speak and respond in
# ever more natural sounding voices. More impressive still is
# modern machine translation (1). Anyone with a smartphone
# has access to applications that allow them to say a sentence in
# one language and then see and hear its translation in another.
# Human ability still far exceeds machines in most language
# tasks, but these systems work well enough to be used by
# billions of people everyday.
#
# What underlies these successes, and what limitations do
# these systems face? We argue that successes to date come from
# ever more eﬀective methods for exploiting principles of neural
# computation that human language users also exploit. We then
# note that the work remains limited in that it largely treats
# language separately from the larger task of understanding
# the world around us. This leads us to propose an integrated
# approach to building a system that truly understands, in which
# language plays a key role in concert with other sources of input.
# We discuss the challenges facing further development of the
# approach and propose future steps toward addressing these
# challenges.
#
# Principles of Neural Computation
#
# The principles of neural computation are domain general prin-
# ciples inspired by the human brain. They were ﬁrst articulated
# in the 1950s (2) and further developed in the 1980s in the
# Parallel Distributed Processing (PDP) framework for modeling
# cognition (3). A central idea of this approach is that struc-
# ture in language and other cognitive domains is an emergent
#
# 1
#
# phenomenon, captured in learned connection weights and re-
# sulting in context-sensitive, distributed representations whose
# characteristics reﬂect a gradual, input-statistics dependent,
# learning process (4). The models treat the symbols and rules
# of classical linguistic theory as consequences of processing and
# learning, not entities whose structure must be built in. Instead
# of discrete symbols for linguistic units, these models rely on
# patterns of activity often called embeddings over arrays of
# neuron-like processing units. Instead of explicit systems of
# rules, they rely on learned matrices of connection weights to
# map patterns on one set of units into patterns on others.
#
# Another key principle is mutual constraint satisfaction (5).
# For example, the meaning of a sentence depends on its struc-
# ture (its organization into constituent phrases); but so too can
# the structure depend on the meaning. Consider the sentence A
# boy hit a man with a __. If the missing word is bat, with a bat
# is read as part of a verb phrase headed by hit, and speciﬁes the
# instrument used to carry out the action. But if beard ﬁlls the
# blank, with a beard is a part of a noun phrase describing who
# was hit. Even the segmentation of spoken or written language
# into elementary segments (e.g., letters) depends in part on
# meaning and context, as illustrated in Fig. 1. Rumelhart (5)
# sketched an interactive model of language understanding in
# which estimates of probabilities about all aspects of an input
# constrain estimates of the probability of every other aspect.
# The idea was captured in a model of context eﬀects in per-
# ception (6). Later work (7, 8) linked these ideas to energy
# minimization in statistical physics. Neural language modeling
# research, which we now describe, incorporates these principles.
#
# Neural Language Modeling
#
# An Early Neural Language Model. Elman (9) built on the prin-
# ciples above to demonstrate how neural models can capture
# key characteristics of language structure through learning, a
# feat once considered impossible (10). The model provides a
# starting point for understanding recent developments. Elman
# used the recurrent neural network shown in Fig. 2a. The
# network was trained to predict the next word in a sequence
# (w(t + 1)) based on the current word (w(t)) and its own hidden
# (that is, learned internal) representation from the previous
# time step (h(t − 1)). These two inputs are each multiplied
# by a matrix of connection weights (represented by the arrows
# labeled Whi and Whh) to produce vectors that are added to
# produce a vector of inputs to the hidden layer of units. The
#
# JM, FH, MR, JB, and HS wrote the paper.
#
# The authors declare no conﬂict of interest.
#
# 1J.B. and H.S. contributed equally.
#
# 2 To whom correspondence should be addressed. E-mail: jlmccstanford.edu, felixhill@google.com,
# marirudolph@gmail.com, jasonbaldridge@google.com or inquiries@cislmu.org
#
# Fig. 1. Two handwritten sentences illustrating how context inﬂuences the identiﬁcation
# of letters in written text. The visual input we read as went in the ﬁrst sentence and
# event in the second is the same bit of Rumelhart’s handwriting, cut and pasted into
# each of the two contexts. Reprinted from (5).
#
# elements of this vector undergo a transformation limiting the
# range of activation values, resulting in the hidden layer repre-
# sentation. This in turn is multiplied with the matrix of weights
# to the output layer from the hidden layer (Woh) to generate a
# vector used to predict the probability of each of the possible
# successor words. Learning in this and other neural models is
# based on the discrepancy between the network’s output and
# the actual next word; the values of the connection weights
# are adjusted by a small amount to reduce the discrepancy.
# The network is called recurrent because the same connection
# weights (denoted by arrows in the ﬁgure) are used to process
# each successive word; the hidden representation h(t) becomes
# the context representation h(t − 1) for the next time step.
#
# Elman demonstrated two crucial ﬁndings. First, after train-
# ing his network to predict the next word in simple sentences like
# man eats bread, dog chases cat, and girl sleeps, the network’s
# representations captured the syntactic distinction between
# nouns and verbs (9). It also captured interpretable subcate-
# gories, as shown by a hierarchical clustering of the hidden-layer
# pattern (h(t)) for each word in the training materials (Fig. 2b).
# This illustrates a key feature of learned representations in neu-
# ral models: they capture speciﬁc as well as general or abstract
# information. By using a diﬀerent learned representation for
# each word, the speciﬁc predictive consequences of that word
# can be exploited. Because representations for words that make
# similar predictions are similar, and because neural networks
# exploit similarity, the network can share knowledge about
# predictions among related words. Second, Elman (11) used
# both simple sentences like boy chases dogs and more complex
# ones like boy who sees girls chases dogs. In the more complex
# case, the verb chases must agree with the ﬁrst noun (boy), not
# the closest noun (girls), since the sentence contains a main
# clause (boy chases dogs) interrupted by an embedded clause
# (boy [who] sees girls). The model learned to predict the verb
# form correctly despite the intervening clause, showing that it
# acquired sensitivity to the syntactic structure of language, and
# not just local co-occurrence statistics in its learned connections
# and distributed representations.
#
# Scaling Up to Process Natural Text. Elman’s task—predicting
# the next word in a sequence—has been central to neural lan-
# guage modeling. However, Elman trained his networks with
# only tiny fragments of what were eﬀectively toy languages.
# For many years, it seemed they would not scale up. Beginning
# about 10 years ago, advances in machine language process-
# ing began to overcome this limitation for neural models. We
# describe two crucial developments next.
#
# Long-distance dependencies and pretrained word embeddings. A
# challenge for language prediction is the indeﬁnite length of
#
# Fig. 2. (a) Elman’s (1990) simple recurrent network and (b) his hierarchical clustering
# of the representations it learned, reprinted from (9).
#
# the context that might be relevant. Consider this passage:
#
# John put some beer in a cooler and went out with his
# friends to play volleyball. Soon after he left, someone
# took the beer out of the cooler. John and his friends
# were thirsty after the game, and went back to his
# place for some beers. When John opened the cooler,
# he discovered that the beer was ___.
#
# Here a reader expects the missing word to be gone. Yet if
# we replaced someone took the beer with someone took the ice
# the expected word would be warm instead. Furthermore, any
# amount of additional text between beer and gone would not
# change the predictive relationship. Elman’s network could
# take only a few words of context into account, reﬂecting a
# larger challenge known as the vanishing gradient problem (12).
# In essence, the magnitude of the learning signal that deter-
# mines the adjustments to connection weights tends to decrease
# exponentially as the number of layers of weights between an
# input and an output increases. The development of neural
# network modules called Long-Short-Term-Memory (LSTM)
# modules (13) that partially overcame this limitation was there-
# fore crucial, greatly increasing the contextual range of neural
# models. In another crucial development, researchers began
# to use pre-trained word embeddings derived from learning
# predictive relationships among words (14, 15). When training
# a neural model for a speciﬁc task, such embeddings could then
# be used to directly represent training words in the model’s
# input. The embeddings were based on the aggregate statistics
# of large text corpora, and captured both general and speciﬁc
# predictive relationships, supporting generalization at both gen-
# eral and speciﬁc levels. Using these embeddings, task-focused
# models trained with relatively small data sets could generalize
# what they learned from training on frequent words (such as
# sofa) to infrequent words with similar predictive relationships
# (such as settee).
#
# A limitation of the above approach is that the same rep-
# resentation of a word is used every time it occurs, regardless
# of context. However, in line with the principle of mutual
# constraint satisfaction, humans interpret words, including am-
# biguous words like bank, in accordance with the context (16),
# rapidly assigning a contextually appropriate meaning to each
# word based on all other words. A ﬁxed embedding also limits
# predicting other words; the predictive implication of the word
# bank depends on which kind of bank is involved. Initial steps
#
# McClelland et al.: Language understanding in humans and machines
#
# 2
#
# for every intervening word, the context reaches the target
# directly. Likewise, gradient learning signals skip over the inter-
# vening words, avoiding the dissipation of learning signal that
# would otherwise occur.
#
# BERT-based models have produced remarkable improve-
# ments on a wide range of language tasks (25, 26). The models
# can be pre-trained on massive text corpora, providing useful
# representations for subsequent tasks for which little speciﬁc
# training data exists (27). These models seem to capture syn-
# tactic, semantic and world knowledge and they are beginning
# to address tasks once thought beyond their reach. For ex-
# ample, Winograd Schema challenge (28) requires determining
# the referent of a pronoun (here it) in a sentence such as The
# trophy did not ﬁt in the suitcase because it was too ___. For a
# person, world knowledge tells us that if the missing word is big
# the referent must be the trophy, but if it is small the referent
# must be the suitcase. The latest models achieve ever-higher
# scores on benchmarks including variants of the Winograd chal-
# lenge (29). However, variants of test materials that do not
# fool humans continue to stymie even the best models (30), and
# further reﬁnements in the models and their assessment will be
# required before it will be clear what such models can achieve.
#
# The Human Integrated Understanding System (IUS)
#
# Situations and objects. Despite the successes of neural lan-
# guage modeling, an important limitation is that these models
# are purely language based. We need models in which lan-
# guage is a part of an integrated understanding system (IUS)
# for understanding and communicating about the situations
# we encounter and the objects that participate in them. Rep-
# resentations of situations constitute our models of our world
# and guide our behavior and our interpretation of language.
# Indeed, resolving the referent of the pronoun in a Winograd
# sentence would follow from building a representation of the
# situation the sentence describes. In the situation in which a
# trombone does not ﬁt in a suitcase, the natural reason would
# be that the trombone is too big or the suitcase too small; the
# identity of the referent of the pronoun follows from realizing
# this. Thus, solving the Winograd Schema challenge is a natu-
# ral byproduct of the human language understanding process.
# In short, we argue that language evolved for communication
# about situations and our systems should address this goal.
#
# Situations can be concrete and static, such as one where
# a cat is on a mat, or they may be events such as one where
# a boy hits a ball. They can be conceptual, social or legal,
# such as one where a court invalidates a law. They may even
# be imaginary. The objects may be real or ﬁctitious physical
# objects or locations; animals, persons, groups or organizations;
# beliefs or other states of mind; or entities such as theories,
# laws or constitutions. Here we focus on concrete situations,
# considering other cases below. Our proposal builds on classic
# work in linguistics (31, 32), human cognition (33), artiﬁcial
# intelligence (34), and an early PDP model (35) and dovetails
# with an emerging perspective in cognitive neuroscience (36).
# As humans process language, we construct a representation
# of the situation the language describes from the stream of
# words and other available information. Words and their se-
# quencing serve as clues to meaning (37) that jointly constrain
# the understanding of the situation and each object participat-
# ing in it (35). Consider this passage:
#
# John spread jam on a slice of bread. The knife had
#
# Fig. 3. High-level depiction of one stage of the bidirectional attention architecture,
# shown constructing a contextually appropriate representation of bank based on other
# words in the same sentence. Diagonal lines show how inputs from other positions
# reach bank ’s position; the same occurs at all word positions. See text for details.
#
# toward context sensitivity (17) recognize this limitation. We
# consider a fuller solution in the next section.
#
# Attention and fully contextualized embeddings. Breakthroughs in
# neural language modeling have come from recent models that
# construct fully contextualized word representations (18–22).
# The models represent words via a mutual constraint satis-
# faction process in which each word in a text span inﬂuences
# the representation of every other word. BERT (20) is a key
# model in this class, illustrated in Fig. 3 as it encodes the end
# of the sentence John reached the bank of the river (example
# from (23)). An initial context-independent representation of
# each word is ﬁrst combined with a positional representation
# (bottom row of boxes in the ﬁgure). Then, a separate copy of
# the same neural network module updates the representation in
# each position with input from all other positions. This process
# uses queries (red) at each position that are compared to keys
# (yellow) at all positions to form weightings (mauve boxes) that
# determine how strongly the values (blue) from each position
# contribute to the combined attention vectors (grey boxes) that
# provide context-sensitivity. The computation iterates over
# many layers, allowing words whose representations have been
# inﬂuenced by their context to inﬂuence the representations of
# other words. The process allows selection among alternative
# distinct meanings of a word like bank as well as graded shading
# of word meaning by context, for example assigning diﬀerent
# emotional valance to the dogs in the dog wagged its tail and
# the dog snarled.
#
# Key ingredients of the contemporary models are (i) bidi-
# rectionality of information ﬂow during processing and (ii) an
# attention mechanism, which replaces the LSTM mechanism to
# enhance the exploitation of context. Bidirectionality matters
# because the meaning of a word in context depends on what
# comes after it as well as what comes before; in the example
# sentence, the last word, river, determines the meaning of bank.
# While it is remarkable how much can be done with strictly left-
# to-right constraint propagation (24), bidirectionality allows
# neural models to implement a mutual constraint satisfaction
# process in which the representation of each word depends on
# all other words. The attention mechanism distinguishes these
# models from earlier LSTM-based neural language models, and
# is used in both bidirectional and left-to-right models. Atten-
# tion has proven to be even more eﬀective than the LSTM
# mechanism in allowing networks to capture long-distance de-
# pendencies. Rather than requiring information about a context
# word to reach a target word through an iteration of the LSTM
#
# McClelland et al.: Language understanding in humans and machines
#
# 3
#
# been dipped in poison. John ate the bread and soon
# began to feel sick.
#
# We can make many inferences here: that the jam was spread
# with the poisoned knife, that some of the poison was trans-
# ferred to the bread, and that this may have led to John’s
# sickness. Note that the entities here are objects, not words,
# and the situation could instead be conveyed by a silent movie.
# Evidence that humans construct situation representations
# comes from classic work by Bransford and colleagues (33, 38).
# This work demonstrates that (1) we understand and remember
# texts better when we can relate the statements in the text
# to a familiar situation; (2) information that conveys aspects
# of the situation can be provided by a picture accompanying
# the text; (3) the characteristics of the objects we remember
# depend on the situations in which they occurred in a text;
# (4) we represent in memory objects not explicitly mentioned
# in texts; and (5) after hearing a sentence describing spatial
# or conceptual relationships among objects, we retain mem-
# ory for these relationships rather than the linguistic input.
# Further, evidence from eye movements shows that people use
# linguistic and non-linguistic input jointly and immediately as
# they process language in context (39). For example, just after
# hearing The man will drink ... participants look at a full wine
# glass rather than an empty beer glass (40). After hearing The
# man drank, they look at the empty beer glass. Thus, language
# understanding involves constructing–in real time–a represen-
# tation of the situation being described by language input,
# including the objects involved and their spatial relationships
# with each other, using visual and linguistic inputs.
#
# The understanding system in the brain. Fig. 4 presents a de-
# piction of our proposed integrated understanding system. Our
# proposal is both a theory of the brain basis of understanding
# and a proposed architecture for future language understanding
# research. It is largely consistent with proposals in (36). First,
# we focus on a part of the system, called the neocortical sys-
# tem, that is suﬃcient to combine linguistic and non-linguistic
# input to understand the object and situation referred to upon
# hearing a sentence containing the word bat while observing
# a corresponding situation in the world. This system consists
# of the blue ovals (corresponding to pools of neurons in the
# brain) and blue arrows (connections between these pools) in
# the ﬁgure. One population subserves a visual representa-
# tion/embedding of the given situation, and another subserves
# a non-semantic linguistic representation capturing the sound
# structure (phonology) of co-occurring spoken language. The
# third represents objects participating in the situation, and
# the fourth represents the overall situation itself. Within each
# pool, and between each connected pair of pools, the neurons
# are reciprocally interconnected via learning-dependent path-
# ways allowing mutual constraint satisfaction among all of the
# elements of each of the embedding types. Brain regions for
# representing visual and linguistic inputs are well-established,
# and the evidence for their involvement in a mutual constraint
# satisfaction process is substantial (41). Here we focus on the
# evidence for object and situation representations in the brain.
#
# Object representations. A brain area near the front of the tempo-
# ral lobe houses neurons whose activity provides an embedding
# capturing the properties of an object someone is considering
# (42). Damage to this area impairs the ability to name objects,
# to grasp objects correctly in service of their intended use, to
#
# Fig. 4. Proposed integrated understanding system (IUS). The blue box contains
# the neocortical system, with each oval forming an embedding (representation) of a
# speciﬁc kind of information. Blue arrows represent learned connections that allow
# the embeddings to constrain each other. The red box contains the medial temporal
# lobe system, thought to provide a network that stores an integrated embedding of the
# neocortical system state. The red arrow represents fast-learning connections that
# bind the elements of this embedding together for later reactivation and use. Green
# arrows connecting the red and blue ovals support bidirectional inﬂuences between
# the two systems. (A) and (B) are two example inputs discussed in the main text.
#
# match objects with their names or the sounds that they make,
# and to pair objects that go together with each other, either
# from their names or from pictures. Models that capture these
# ﬁndings (43) treat this area as the hidden layer of an interac-
# tive, recurrent network with bidirectional connections to other
# layers corresponding to brain areas that represent diﬀerent
# types of object properties including the object’s name. In these
# models, an input to any of these other layers activates the cor-
# responding pattern in the hidden layer, which in turn activates
# the corresponding patterns in the other layers, supporting, for
# example, the ability to produce the name of an object from
# visual input. Damage (simulated by removal of neurons in the
# hidden layer) degrades the model’s representations, capturing
# the patterns of errors made by patients with the condition.
#
# Situation representations. The situation representation speciﬁes
# the event or situation conveyed by visual and/or language
# input. Evidence from behavioral studies indicates that con-
# struction of a situation representation can occur with or with-
# out language input (44) or through the convergent inﬂuence
# of both sources of information (40). Cognitive neuroscience
# research supports the idea that the situation representation
# arises in a set of interconnected brain areas primarily located
# in the frontal and parietal lobes (36, 45). In recent work, brain
# imaging data is used to analyze the time-varying patterns
# of neural activity that arise during the processing of a tem-
# porally extended event sequence. The activity patterns that
#
# McClelland et al.: Language understanding in humans and machines
#
# 4
#
# represent corresponding events in a sequence are largely the
# same, whether the information about the sequence comes from
# watching a movie, hearing or reading a narrative description,
# or recalling the movie after having seen it (46, 47).
#
# Situation-speciﬁc constraints. An important feature of our brain-
# inspired proposal is the use of distinct situation and object
# representations, and the idea that the constraints on the par-
# ticipating objects are mediated by the situation representation.
# The advantage of this is that it allows these constraints to
# be situation-speciﬁc. For example, the dogs in the events de-
# scribed by the sentences the boy ran to the dog and the boy ran
# from the dog are likely to be diﬀerent, and a comprehender will
# represent them diﬀerently (38). In general, context-sensitivity
# is best captured by a mediating representation rather than
# direct associations among constituents (48). While BERT-like
# models might partially capture such constraints implicitly, an
# integrated situation representation may be more eﬀective.
#
# In summary, the brain contains distinct areas that represent
# each input modality and the objects and situations conveyed
# through them, computing these representations through a
# mutual constraint satisfaction process combining language and
# other inputs. Emulating this architecture in machines could
# contribute to achieving human-level language understanding.
# What would a computational instantiation of our system look
# like? It is likely that a biologically realistic version would
# diﬀer in some ways from the most eﬀective machine version.
# Contemporary attention-based language models can deploy
# attention over tens to thousands of words kept in their current
# system state, but evidence from brain imaging data collected
# during movie comprehension suggests that activation states in
# visual, speech, and object areas change rapidly as events unfold,
# while the brain state tends to be more constant, changing only
# at event boundaries in brain areas associated with situation
# representations (47). In humans, spanning longer temporal
# windows, including multi-event narratives, appears to require
# the complementary learning system we consider next.
#
# Complementary Learning Systems. Learning plays a crucial
# role in understanding. The knowledge in the connection
# weights in the neural networks we have described is acquired
# through the accumulation of very small adjustments based on
# each experience. The connection weights gradually become
# sensitive to subtle higher-order statistical relationships, taking
# more and more context into account as learning continues (49),
# and exhibiting sensitivity both to general and recurring speciﬁc
# information (e.g., names of close friends and famous people).
# In our proposed architecture, this gradual process occurs in
# all the pathways represented by the blue arrows in Fig. 4, just
# as it does in the artiﬁcial neural language models considered
# above. However, this learning mechanism is not well suited to
# acquiring new information rapidly, and attempting to learn
# speciﬁc new information quickly by focused repetition leads
# to catastrophic interference with what is already known (50).
# Yet, humans can often rely on information presented just
# once at an arbitrary time in the past to inform our current
# understanding. Returning to the beer John left in the cooler,
# to anticipate that John will not ﬁnd the beer when he opens
# the cooler again, we must rely on information acquired when
# we ﬁrst heard about the beer being stolen. Such situations
# are ubiquitous, and a learning system must be able to exploit
# such information, but BERT and the other models described
#
# previously are limited in this way. Though some models hold
# long word sequences in an active state, when one text is
# replaced with another, only the small connection adjustments
# described above remain, leaving these systems without access
# to the speciﬁcs of the prior information.
#
# The human brain contains a system that addresses this
# limitation. Consider a situation in which someone sees a pre-
# viously unfamiliar object and hears a spoken statement about
# it, as illustrated in Fig. 4B. The visual input provides one
# source of information about the object (a previously unfamiliar
# animal), while the linguistic input provides its name. Humans
# show robust learning after just two brief exposures to such
# pairings (51). This form of learning depends on the hippocam-
# pus and adjacent areas in the medial temporal lobes (MTL)
# of the brain (51). While details of the role of the MTL in
# learning and memory continue to be debated (52, 53), there is
# consensus that the MTL is crucial for the initial formation of
# new memories, including memories for speciﬁc events and their
# constituent objects and situations, while general knowledge,
# the ability to understand language, and previously acquired
# skills are unaﬀected by MTL damage.
#
# The evidence from MTL damage suggests there is a fast
# learning system in the MTL. According to complementary
# learning systems theory (CLST) (54–56) this system (shown
# in red in Fig. 4) provides an integrated representation of the
# understanding system state, and employs modiﬁable connec-
# tions within the MTL (red arrow) that can change rapidly to
# support new learning based on a single experience. The green
# arrows represent connections that carry information between
# the neocortical (blue) and MTL (red) systems so the systems
# can inﬂuence each other.
#
# Let us consider how, according to CLST, a human can learn
# about the numbat (see Fig. 4B) from an experience seeing
# it and hearing a sentence about it (56). The input to the
# MTL is thought to be an embedding that captures (i.e., can
# be used to reconstruct) the patterns in the neocortical areas
# that arise from the experience. Networks within the MTL (not
# shown) map the MTL input representation to a sparser one
# deep inside the MTL, maximizing distinctness and minimizing
# interference among experiences (54). Large connection weight
# changes within the MTL associate the elements of the sparse
# representation with each other and with the MTL input repre-
# sentation. When the person hears the word numbat in a later
# situation, connections to the MTL from the neocortex activate
# neurons in the MTL input representation. The weight changes
# that occurred on prior exposure support the reconstruction
# of the complete MTL representation, and return connections
# to the neocortex then support approximate reconstruction of
# the visual, speech, object and situation representations formed
# during the initial exposure to the numbat. These representa-
# tions are the explicit memory for the prior experience, allowing
# the cortical network to use what it learned from one prior
# exposure to contribute to understanding the new situation.
#
# Integrating information into the neocortex. How can knowledge ini-
# tially dependent on the MTL be integrated into the neocor-
# tex? According to CLST (55), the neocortex learns gradually
# through interleaved presentations of new and familiar items;
# this process avoids interference of new items with what is al-
# ready known. Interleaved learning can occur through ongoing
# experience, as would happen if, for example, we acquire a pet
# numbat that we then see every day, while continuing to have
#
# McClelland et al.: Language understanding in humans and machines
#
# 5
#
# other experiences. Interleaving may also occur during rest
# or sleep through reactivation and replay of patterns stored
# in the MTL: Indeed, spontaneous replay of short snippets of
# previously experienced episodes occurs within the MTL during
# sleep and between behavioral episodes (see (56) for review).
# In summary, the human brain contains complementary
# learning systems that support the simultaneous use of many
# sources of information as we seek to understand an experienced
# situation. One of these systems acquires an integrated system
# of knowledge gradually through interleaved learning, includ-
# ing our knowledge of the meanings of words, the properties
# of frequently-encountered objects, and the characteristics of
# familiar situations. The other complements this system to
# allow information from speciﬁc experiences to be brought to
# bear on the interpretation of a current situation.
#
# Toward an Artiﬁcial Integrated Understanding System
#
# Here we consider current deep learning research that is taking
# steps consistent with our IUS proposal, and point toward fu-
# ture directions that will be needed to achieve a truly integrated
# and fully functional understanding system. We begin within
# the context of language grounded within concrete visual and
# physical situations, then consider the role of memory, and
# ﬁnally turn to the extension of the approach to address under-
# standing of more abstract objects, situations, and relations.
#
# Mapping vision and language to representations of objects.
# How might a model learn about situations that can occur
# in the world? The need for an artiﬁcial system of language
# understanding to be grounded in the external world has long
# been discussed. An early example is Winograd’s SHRDLU
# system (57), which produced and responded to language about
# a simulated physical world. Deep learning has enabled joint,
# end-to-end training of perceptual input and language (i.e., in
# a single synchronous optimization process). Recent advances
# with such models have greatly improved performance, resulting
# in applications transforming user experiences. When presented
# with a photograph, networks can now answer questions such
# as what is the man holding? or what color is the woman’s
# shirt? (58), demonstrating an ability to combine information
# from vision and language to understand a class of situations.
# A very recent model (59) explicitly represents the objects in
# a scene, their properties, and their relations to other objects in
# a designed scene graph with slots for objects, their properties,
# and relations. It encodes questions as a series of instructions
# to ﬁnd a target object or relation by searching the graph to
# answer a query. For example, the question what is the object
# beside the yellow bowl? can be answered by ﬁnding the yellow
# bowl, ﬁnding an object linked to it with the ‘beside’ relation,
# and then reading out this object’s identity. The approach
# advances the state of the art, though a large gap relative
# to humans remains. The model shares important properties
# with our proposal in that it explicitly treats language input
# as querying the model’s representation of the objects in the
# scene, and their conceptual properties. A natural extension
# consistent with IUS would be to build up scene representations
# using a combination of visual input and language, allowing
# text to enrich the representations of objects and relations.
#
# A question this work raises is whether to build structured
# representations into one’s model. This is advocated in (59),
# but natural structure exhibits ﬂexible embedding relationships
#
# and is often only approximately characterized by explicit tax-
# onomies, motivating use of emergent connection-based rather
# than hard-coded representational structures (60). A challenge,
# then, is to achieve comparable performance with models in
# which these concept-based object and relational representa-
# tions emerge through learning.
#
# Embodied models for language understanding. Beyond the
# integration of vision and language, as illustrated in Fig. 4, we
# see progress coming from an even fuller integration of many
# additional information sources. Every source provides a basis
# for distinct learning objectives and enables information that
# is salient in one source to bootstrap learning and inference in
# the other. Important additional sources of information include
# non-language sound, touch and force-sensing, and information
# about one’s own actions.
#
# Incorporating additional information sources will allow an
# IUS to go beyond answering questions about static images.
# Since image data has no temporal aspect, such models lack
# experience of events or processes. While models that jointly
# process video and language (61) may acquire some sensitiv-
# ity to event structure and commonplace causal relationships,
# these systems do not make choices aﬀecting the world they
# observe. Ultimately, an ability to link one’s actions to their
# consequences as one intervenes in the observed ﬂow of events
# and interacts with other agents should provide the strongest
# basis for acquiring notions of cause and eﬀect, of agency, and
# of self and others.
#
# These considerations motivate recent work on agent-
# based language learning in simulated interactive 3D environ-
# ments (62–65). In (66), an agent was trained to identify, lift,
# carry and place objects relative to other objects in a virtual
# room, as speciﬁed by simpliﬁed language instructions. At each
# time step, the agent received a ﬁrst-person visual observation
# (pixel-based image) that it processed to produce a representa-
# tion of the scene. This was concatenated to the ﬁnal state of
# an LSTM that processed the instruction, then passed to an
# integrative LSTM whose output was used to select a motor
# action. The agent gradually learned to follow instructions of
# the form ﬁnd a pencil,
# lift up a basketball and put the teddy
# bear on the bed, encompassing 50 objects, and requiring up
# to 70 action steps to complete. Such instructions require the
# construction of representations based on language stimuli that
# enable the identiﬁcation of objects and relations across space
# and time, and the integration of this information to inform mo-
# tor behaviors. Importantly, without building in explicit object
# representations, the system supported the interpretation of
# novel instructions. For instance, an agent trained to lift a set
# of 20 objects in the environment, but only trained to put 10 of
# those in a speciﬁc location could place the remaining objects
# in the same location on command with over 90% accuracy.
#
# Neural models often fail to exhibit systematic generaliza-
# tion, leading some to propose that more structure should be
# built in (67). While the agent’s level of systematicity does
# not reach human levels, this work suggests that grounding lan-
# guage learning can help support systematicity without building
# it in. Critically, the agent’s systematicity was contingent on
# the ego-centric, multimodal and temporally-extended expe-
# rience of the agent. On the same set of generalization tests,
# both an alternative agent with a ﬁxed perspective on a 2D grid
# world and a static neural network classiﬁer that received only
# individual still image stimuli exhibited signiﬁcantly worse gen-
#
# McClelland et al.: Language understanding in humans and machines
#
# 6
#
# tions under consideration can only be communicated through
# language. What is the way forward toward developing models
# that can understand such a complex situation?
#
# Language may have evolved in part to support transmission
# of complex, hierarchical knowledge about tools (71). How-
# ever, utterances also had to support abstraction and complex
# dependencies between concrete objects, as well as social re-
# lationships between speakers. Words themselves provided a
# new abstract substrate for characterizing other words (72).
# Word embeddings are one implementation of this substrate:
# they can characterize abstract words like justice and represents
# without directly grounding them. In humans, encyclopedic
# knowledge grounded in such representations can be acquired
# in an MTL-dependent way from reading an encyclopedia arti-
# cle just once. For machines, forming integrated system state
# representations capturing the content and using a DNC-like
# system for their storage and retrieval might provide a starting
# place for enabling such knowledge to be acquired and used
# eﬀectively.
#
# That said, words are uttered in real world contexts and there
# is a continuum between grounding and language-based linking
# for diﬀerent words and diﬀerent uses of words. For example,
# career is not only linked to other abstract words like work and
# specialization but also to more grounded concepts such as path
# and its extended metaphorical use for discussing the means to
# achieve goals (72). Embodied, simulation-based approaches
# to meaning (73, 74) build on this observation to bridge from
# concrete to abstract situations via metaphor. They posit
# that understanding words like grasp is directly linked to neural
# representations of the action of grabbing and that this circuitry
# is recruited for understanding the word in contexts such as
# grasping an idea. We consider situated agents as a critical
# catalyst for learning about how to represent and compose
# concepts pertaining to spatial, physical and other perceptually
# immediate phenomena—thereby providing a grounded ediﬁce
# that can connect to both the low level brain circuitry for motor
# action and to representations derived primarily from language.
#
# Conclusion. Language does not stand alone. The integrated
# understanding system in the brain connects language to rep-
# resentations of objects and situations and enhances language
# understanding by exploiting the full range of our multi-sensory
# experience of the world, our representations of our motor
# actions, and our memory of previous situations. We have ar-
# gued that the next generation language understanding system
# should emulate this system in the brain and we have sketched
# some aspects of the form such a system might take. While
# we have emphasized understanding of concrete situations, we
# have argued that understanding more abstract language builds
# upon this concrete foundation, pointing toward the possibility
# that it may someday be possible to build artiﬁcial systems that
# understand abstract situations far beyond the concrete and
# the here-and-now. In sum, we have proposed that modeling
# the integrated understanding system in the brain will take us
# closer to capturing human-level language understanding and
# intelligence.
#
# ACKNOWLEDGMENTS. This article grew out of a workshop
# organized by HS at Meaning in Context 3, Stanford University,
# September 2017. We thank Chris Potts for discussion. HS was
# supported by ERC Advanced Grant #740516.
#
# Fig. 5. Left: the (allocentric) agent perspective in a 2D grid-world. The text indicates
# the language instruction, requiring the agent (white striped cell) to visit one of the
# red ﬁgures and move it to the white square. Right: the ﬁrst-person perspective of the
# situated agent, addressing an equivalent task to the one posed in the grid world.
#
# eralization that a fully situated agent (Fig. 5). This underlines
# how aﬀording neural networks access to rich, multi-modal
# interactive environments can stimulate the development of
# capacities that are essential for language learning.
#
# Despite these promising signs, achieving fully human levels
# of generalization remains an important challenge. We propose
# that incorporating an MTL-like fast learning system will help
# address this by allowing new words to be linked to the corre-
# sponding object from just a single episode supporting use of
# the word to refer to the referent in other situations.
#
# An artiﬁcial fast learning system. What might a fast learning
# system in an implementation of an integrated understanding
# system look like? The memory system in the diﬀerentiable
# neural computer (DNC) (68) is one possibility. These systems
# store embeddings derived from past episodes in slots that
# could store Integrated System State representations like those
# we attribute to the human MTL. Alternatively, they could
# store the entire ensemble of states across the visual, speech,
# object, and situation representations. Though we do not
# believe the brain has a separate slot for each memory, it can
# be useful to model it as though it does (56), and artiﬁcial
# systems with indeﬁnite capacity could exceed human abilities
# in this regard. How might the retrieval of relevant information
# work in such a system? The DNC employs a querying system
# similar to the one in BERT and to proposals in the human
# memory literature, whereby the representation retrieved from
# the MTL is weighted by the degree of match between a query
# (which we would treat as coming from the neocortex) and each
# vector stored in memory. Close matches are favored in this
# computation (69), so that when there is a unique match (such
# as a single memory containing a once seen word like numbat),
# the corresponding object and situation representation could
# be retrieved. Retrieval could be based on a combination of
# context and item information, similar to human memory (70).
# Working out the details of such a system presents an exciting
# research direction for the future.
#
# Beyond concrete situations. Our discussion has focused pri-
# marily on concrete situations. However, language allows us to
# discuss abstract ideas and situations, where grounding in the
# physical world can be very indirect and our learning about
# it comes primarily from language-based materials. Consider,
# for example, an understanding of Brexit. Concrete events
# involving actual people have occurred, but the issues and ques-
#
# McClelland et al.: Language understanding in humans and machines
#
# 7
#
# 1. Wu Y, et al. (2016) Google’s neural machine translation system: Bridging the gap between
#
# human and machine translation. -.
#
# world knowledge: Linking anticipatory (and other) eye movements to linguistic processing.
# Journal of Memory and Language 57(4):502–518.
#
# 2. Rosenblatt F (1961) Principles of neurodynamics. perceptrons and the theory of brain mech-
#
# 41. McClelland JL, Mirman D, Bolger DJ, Khaitan P (2014) Interactive activation and mutual con-
#
# anisms. (Spartan Books, Cornell University, Ithaca, New York).
#
# straint satisfaction in perception and cognition. Cognitive science 38(6):1139–1189.
#
# 3. Rumelhart DE, McClelland JL, the PDP research group (1986) Parallel Distributed Process-
# ing. Explorations in the Microstructure of Cognition. Volume 1: Foundations. (The MIT Press,
# Cambridge, MA).
#
# 4. Rumelhart DE, McClelland JL (1986) On learning the past tenses of English verbs in Parallel
# Distributed Processing. Explorations in the Microstructure of Cognition. Volume 2: Psycho-
# logical and Biological Models, eds. McClelland JL, Rumelhart DE, the PDP Research Group.
# (MIT Press), pp. 216–271.
#
# 42. Patterson K, Nestor PJ, Rogers TT (2007) Where do you know what you know? the represen-
#
# tation of semantic knowledge in the human brain. Nature Reviews Neuroscience 8(12):976.
#
# 43. Rogers TT, et al. (2004) Structure and deterioration of semantic memory: a neuropsycholog-
#
# ical and computational investigation. Psychological review 111(1):205–235.
#
# 44. Zwaan RA, Radvansky GA (1998) Situation models in language comprehension and memory.
#
# Psychological bulletin 123(2):162–185.
#
# 45. Ranganath C, Ritchey M (2012) Two cortical systems for memory-guided behaviour. Nature
#
# 5. Rumelhart DE (1977) Toward an interactive model of reading in Attention & Performance VI,
#
# Reviews Neuroscience 13:713. Review Article.
#
# ed. Dornic S. (LEA, Hillsdale, NJ), pp. 573–603.
#
# 6. McClelland JL, Rumelhart DE (1981) An interactive activation model of context effects in letter
#
# perception: I. an account of basic ﬁndings. Psychological review 88(5):375.
#
# 46. Zadbood A, Chen J, Leong Y, Norman K, Hasson U (2017) How we transmit memories to
# other brains: Constructing shared neural representations via communication. Cerebral Cor-
# tex 27(10):4988–5000.
#
# 7. Hopﬁeld JJ (1982) Neural networks and physical systems with emergent collective computa-
#
# 47. Baldassano C, et al. (2017) Discovering event structure in continuous narrative perception
#
# tional abilities. Proceedings of the national academy of sciences 79(8):2554–2558.
#
# and memory. Neuron 95(3):709–721.
#
# 8. Ackley DH, Hinton GE, Sejnowski TJ (1985) A learning algorithm for boltzmann machines.
#
# 48. Hinton GE (1981) Implementing semantic networks in parallel hardware in Parallel Models of
#
# Cognitive science 9(1):147–169.
#
# Associative Memory, eds. Hinton GE, Anderson JA. (Erlbaum), pp. 161–187.
#
# 9. Elman JL (1990) Finding structure in time. Cognitive Science 14:179–211.
#
# 49. Cleeremans A, McClelland JL (1991) Learning the structure of event sequences. Journal of
#
# 10. Gold EM (1967) Language identiﬁcation in the limit. Information and control 10(5):447–474.
# 11. Elman JL (1991) Distributed representations, simple recurrent networks, and grammatical
#
# structure. Mach. Learn. 7(2/3):195–225.
#
# 12. Hochreiter S, Bengio Y, Frasconi P, Schmidhuber J (2001) Gradient ﬂow in recurrent nets: the
# difﬁculty of learning long-term dependencies in A Field Guide to Dynamical Recurrent Neural
# Networks, eds. Kremer SC, Kolen JF. (IEEE Press).
#
# Experimental Psychology: General 120(3):235.
#
# 50. McCloskey M, Cohen NJ (1989) Catastrophic interference in connectionist networks: The
# sequential learning problem in Psychology of learning and motivation. (Elsevier) Vol. 24, pp.
# 109–165.
#
# 51. Warren DE, Duff MC (2019) Fast mappers, slow learners: Word learning without hippocam-
#
# pus is slow and sparse irrespective of methodology. Cognitive neuroscience pp. 1–3.
#
# 13. Hochreiter S, Schmidhuber J (1997) Long short-term memory.
#
# Neural computation
#
# 52. Squire LR (1992) Memory and the hippocampus: a synthesis from ﬁndings with rats, mon-
#
# 9(8):1735–1780.
#
# 14. Collobert R, et al. (2011) Natural language processing (almost) from scratch. Journal of
#
# Machine Learning Research 12(Aug):2493–2537.
#
# 15. Mikolov T, Sutskever I, Chen K, Corrado GS, Dean J (2013) Distributed representations of
# words and phrases and their compositionality in Neural Information Processing Systems. pp.
# 3111–3119.
#
# 16. Simpson GB (1981) Meaning dominance and semantic context in the processing of lexical
#
# ambiguity. Journal of verbal learning and verbal behavior 20(1):120–136.
#
# 17. Rudolph M, Ruiz F, Blei D (2017) Structured embedding models for grouped data in Advances
#
# in Neural Information Processing Systems.
#
# 18. Peters ME, et al. (2018) Deep contextualized word representations. CoRR abs/1802.05365.
# 19. Vaswani A, et al. (2017) Attention is all you need in Advances in Neural Information Process-
#
# ing Systems 30. (Curran Associates, Inc.), pp. 5998–6008.
#
# 20. Devlin J, Chang MW, Lee K, Toutanova K (2018) BERT: Pre-training of Deep Bidirectional
#
# Transformers for Language Understanding. ArXiv e-prints.
#
# keys, and humans. Psychological review 99(2):195.
#
# 53. Yonelinas A, Ranganath C, Ekstrom A, Wiltgen B (2019) A contextual binding theory of
# episodic memory: systems consolidation reconsidered. Nature Reviews Neuroscience.
# 54. Marr D (1971) Simple memory: a theory for archicortex. Philosophical Transactions of the
#
# Royal Society of London B: Biological Sciences 262(841):23–81.
#
# 55. McClelland JL, McNaughton BL, O’Reilly RC (1995) Why there are complementary learning
# Insights from the successes and failures of
#
# systems in the hippocampus and neocortex:
# connectionist models of learning and memory. Psychological Review 102(3):419–457.
# 56. Kumaran D, Hassabis D, McClelland JL (2016) What learning systems do intelligent agents
# need? Complementary learning systems theory updated. Trends in Cognitive Sciences
# 20(7):512–534.
#
# 57. Winograd T (1972) Understanding natural language. Cognitive psychology 3(1):1–191.
# 58. MacLeod H, Bennett CL, Morris MR, Cutrell E (2017) Understanding blind people’s experi-
# ences with computer-generated captions of social media images in Proceedings of the 2017
# CHI Conference on Human Factors in Computing Systems. (ACM), pp. 5988–5999.
#
# 21. Yang Z, et al. (2019) Xlnet: Generalized autoregressive pretraining for language understand-
#
# 59. Hudson DA, Manning CD (2019) Learning by abstraction: The neural state machine. arXiv
#
# 22. Dehghani M, Gouws S, Vinyals O, Uszkoreit J, Kaiser L (2018) Universal transformers. CoRR
#
# ing. CoRR abs/1906.08237.
#
# abs/1807.03819.
#
# 23. Uszkoreit J (2017) Transformer: A novel neural network architecture for language understand-
#
# ing, https://ai.googleblog.com/2017/08/transformer-novel-neural-network.html.
#
# 24. Radford A, Narasimhan K, Salimans T, Sutskever I (2018) Improving language understanding
#
# by generative pre-training. OpenAI Preprint.
#
# preprint arXiv:1907.03950.
#
# 60. Rumelhart DE, Smolensky P, McClelland JL, Hinton G (1986) Pdp models of schemata and
# sequential thought processes in pdp models. Parallel distributed processing: Explorations in
# the microstructure of cognition 2:3–57.
#
# 61. Yu H, Wang J, Huang Z, Yang Y, Xu W (2016) Video paragraph captioning using hierarchical
# recurrent neural networks in Proceedings of the IEEE conference on computer vision and
# pattern recognition. pp. 4584–4593.
#
# 25. Devlin J, Chang MW, Lee K, Toutanova K (2018) Bert: Pre-training of deep bidirectional
#
# 62. Hermann KM, et al. (2017) Grounded language learning in a simulated 3d world. arXiv
#
# transformers for language understanding. arXiv preprint arXiv:1810.04805.
#
# preprint arXiv:1706.06551.
#
# 26. Wang A, et al. (2018) Glue: A multi-task benchmark and analysis platform for natural lan-
#
# guage understanding. arXiv preprint arXiv:1804.07461.
#
# 27. Wang A, et al. (2019) Superglue: A stickier benchmark for general-purpose language under-
#
# standing systems. arXiv preprint arXiv:1905.00537.
#
# 28. Levesque H, Davis E, Morgenstern L (2012) The winograd schema challenge in Thirteenth
# International Conference on the Principles of Knowledge Representation and Reasoning.
# 29. Raffel C, Shazeer N, Roberts A, , et al. (2019) Exploring the limits of transfer learning with a
#
# uniﬁed text-to-text transformer. arXiv preprint arXiv:1910.10683.
#
# 30. Jia R, Liang P (2017) Adversarial examples for evaluating reading comprehension systems in
# Proceedings of the 2017 Conference on Empirical Methods in Natural Language Processing.
# (Association for Computational Linguistics), pp. 2021–2031.
#
# 63. Das R, Zaheer M, Reddy S, McCallum A (2017) Question answering on knowledge bases
# and text using universal schema and memory networks in Proceedings of the 55th Annual
# Meeting of the Association for Computational Linguistic. pp. 358–365.
#
# 64. Chaplot DS, Sathyendra KM, Pasumarthi RK, Rajagopal D, Salakhutdinov R (2017)
# arXiv preprint
#
# task-oriented language grounding.
#
# Gated-attention architectures for
# arXiv:1706.07230.
#
# 65. Oh J, Singh S, Lee H, Kohli P (2017) Zero-shot task generalization with multi-task deep rein-
# forcement learning in Proceedings of the 34th International Conference on Machine Learning-
# Volume 70. (JMLR. org), pp. 2661–2670.
#
# 66. Hill F, et al. (2019) Emergent systematic generalization in a situated agent. arXiv preprint
#
# arXiv:1910.00571.
#
# 31. Lakoff G (1987) Women, Fire, and Dangerous Things.
#
# (The University of Chicago Press,
#
# 67. Lake BM, Salakhutdinov R, Tenenbaum JB (2015) Human-level concept learning through
#
# 32. Langacker RW (1987) Foundations of cognitive grammar: Theoretical prerequisites. (Stan-
#
# 68. Graves A, et al. (2016) Hybrid computing using a neural network with dynamic external mem-
#
# Chicago).
#
# ford university press) Vol. 1.
#
# probabilistic program induction. Science 350(6266):1332–1338.
#
# ory. Nature 538(7626):471–476.
#
# 33. Bransford JD, Johnson MK (1972) Contextual prerequisites for understanding: Some in-
# vestigations of comprehension and recall. Journal of verbal learning and verbal behavior
# 11(6):717–726.
#
# 69. Hintzman DL (1984) Minerva 2: A simulation model of human memory. Behavior Research
#
# Methods, Instruments, & Computers 16(2):96–101.
#
# 70. Polyn SM, Norman KA, Kahana MJ (2009) A context maintenance and retrieval model of
#
# 34. Schank RC (1983) Dynamic memory: A theory of reminding and learning in computers and
#
# organizational processes in free recall. Psychological review 116(1):129.
#
# people. (Cambridge University Press).
#
# 71. Stout D, Chaminade T (2012) Stone tools, language and the brain in human evolution. Philos
#
# 35. John MFS, McClelland JL (1990) Learning and applying contextual constraints in sentence
#
# Trans R Soc Lond B Biol Sci 367(1585):75–87.
#
# 72. Bryson J (2008) Embodiment vs. memetics. Mind and Society 7(1):77–94.
# 73. Lakoff G, Johnson M (1980) Metaphors We Live By. (University of Chicago, Chicago, IL).
# 74. Feldman J, Narayanan S (2004) Embodied meaning in a neural theory of language. Brain
#
# and Language 89:385–392.
#
# comprehension. Artiﬁcial Intelligence 46(1):217 – 257.
#
# 36. Hasson U, Egidi G, Marelli M, Willems RM (2018) Grounding the neurobiology of language
# in ﬁrst principles: The necessity of non-language-centric explanations for language compre-
# hension. Cognition 180:135–157.
#
# 37. Rumelhart DE (1979) Some problems with the notion that words have literal meanings in
#
# Metaphor and thought, ed. Ortony A. (Cambridge Univ. Press, Cambridge, UK), pp. 71–82.
#
# 38. Barclay J, Bransford JD, Franks JJ, McCarrell NS, Nitsch K (1974) Comprehension and se-
#
# mantic ﬂexibility. Journal of Verbal Learning and Verbal Behavior 13(4):471 – 481.
#
# 39. Tanenhaus MK, Spivey-Knowlton MJ, Eberhard KM, Sedivy JC (1995) Integration of visual
# and linguistic information in spoken language comprehension. Science pp. 1632–1634.
# 40. Altmann GT, Kamide Y (2007) The real-time mediation of visual attention by language and
#
# McClelland et al.: Language understanding in humans and machines
#
# 8

# %%
from pdfminer.high_level import extract_text_to_fp

from pdfminer.layout import LAParams
with open(os.path.join(output_dir, '2019.txt'), 'w') as fout:
    with open(os.path.join(sample_pdf_dir, '2019.pdf'), 'rb') as fin:
        txt = extract_text_to_fp(fin, fout, laparams=LAParams(),
                            output_type='text', codec=None)

# %%
# based on https://stackoverflow.com/questions/34606382/pdfminer-extract-text-with-its-font-information

from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.layout import LAParams, LTAnno, LTChar, LTFigure, LTPage, LTTextLine, LTTextBox
from pdfminer.converter import PDFPageAggregator

import pdfminer


def createPDFDoc(fpath):
    fp = open(fpath, 'rb')
    parser = PDFParser(fp)
    document = PDFDocument(parser, password='')
    # Check if the document allows text extraction. If not, abort.
    if not document.is_extractable:
        raise "Not extractable"
    else:
        return document


def createDeviceInterpreter():
    rsrcmgr = PDFResourceManager()
    laparams = LAParams()
    device = PDFPageAggregator(rsrcmgr, laparams=laparams)
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    return device, interpreter

# %%
# print font info
def parse_obj(objs):
    for obj in objs:
        if isinstance(obj, pdfminer.layout.LTTextBox):
            for o in obj._objs:
                if isinstance(o,pdfminer.layout.LTTextLine):
                    text=o.get_text()
                    if text.strip():
                        for c in  o._objs:
                            if isinstance(c, pdfminer.layout.LTChar):
                                print ("fontname %s"%c.fontname)
        # if it's a container, recurse
        elif isinstance(obj, pdfminer.layout.LTFigure):
            parse_obj(obj._objs)
        else:
            pass


# just print all objects recursively
def parse_obj_rec(obj):
    print(obj)
    if getattr(obj, '_objs', None) is not None:
        objs = obj._objs
        for o in objs:
            parse_obj_rec(o)

textline_children = set()
textbox_children = set()

# check possible types of children of box and line
def get_text_types(obj):
    if getattr(obj, '_objs', None) is not None:
        for o in obj._objs:
            get_text_types(o)
    if isinstance(obj, LTTextBox):
        for o in obj._objs:
            textbox_children.add(type(o))
    elif isinstance(obj, LTTextLine):
        for o in obj._objs:
            textline_children.add(type(o))
            
document=createPDFDoc(os.path.join(sample_pdf_dir, "2019.pdf"))
device,interpreter=createDeviceInterpreter()
pages=PDFPage.create_pages(document)
interpreter.process_page(next(pages))
layout = device.get_result()


get_text_types(layout)
print(textline_children)
print(textbox_children)

parse_obj(layout._objs)
# parse_obj_rec(layout)
# Out:
# {<class 'pdfminer.layout.LTAnno'>, <class 'pdfminer.layout.LTChar'>}
# {<class 'pdfminer.layout.LTTextLineHorizontal'>}
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname Times-Roman
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname AHPEAI+LMSans10-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname SGSTNP+LMRoman6-Regular
# fontname SGSTNP+LMRoman6-Regular
# fontname SGSTNP+LMRoman6-Regular
# fontname SGSTNP+LMRoman6-Regular
# fontname SGSTNP+LMRoman6-Regular
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname SGSTNP+LMRoman6-Regular
# fontname SGSTNP+LMRoman6-Regular
# fontname SGSTNP+LMRoman6-Regular
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname SGSTNP+LMRoman6-Regular
# fontname SGSTNP+LMRoman6-Regular
# fontname SGSTNP+LMRoman6-Regular
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname SGSTNP+LMRoman6-Regular
# fontname SGSTNP+LMRoman6-Regular
# fontname SGSTNP+LMRoman6-Regular
# fontname SGSTNP+LMRoman6-Regular
# fontname SGSTNP+LMRoman6-Regular
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname SGSTNP+LMRoman6-Regular
# fontname SGSTNP+LMRoman6-Regular
# fontname SGSTNP+LMRoman6-Regular
# fontname SGSTNP+LMRoman6-Regular
# fontname SGSTNP+LMRoman6-Regular
# fontname UMDNCK+LMRoman5-Regular
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname UMDNCK+LMRoman5-Regular
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname UMDNCK+LMRoman5-Regular
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname UMDNCK+LMRoman5-Regular
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname UMDNCK+LMRoman5-Regular
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VRAOMO+NimbusSanL-Bold
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname JFAOQY+LMMathSymbols7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname JFAOQY+LMMathSymbols7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname JFAOQY+LMMathSymbols7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname JFAOQY+LMMathSymbols7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname VCOSOW+LMRoman7-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# ...
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname VLWLTA+LMMathItalic9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname VLWLTA+LMMathItalic9-Regular
# fontname JBUEEG+LMMathSymbols9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname VLWLTA+LMMathItalic9-Regular
# fontname QYCSPI+LMMathItalic6-Regular
# fontname QYCSPI+LMMathItalic6-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname VLWLTA+LMMathItalic9-Regular
# fontname QYCSPI+LMMathItalic6-Regular
# fontname QYCSPI+LMMathItalic6-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname OKNUIT+LMRoman9-Regular
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu
# fontname YXJLSO+NimbusSanL-Regu

# %%
from collections import deque, Counter

def is_exception(char):
    if isinstance(char, LTAnno):
        return True
    # include any math symbols: based on the characters themselves or the font
    if re.match(r'[`\-\]~!@#$%^&*()_+[\\{}|;:",./<>?0-9\']', char._text) is not None:
#         print(char)
        return True
    
    if re.match(r'^\S*\+\S*[Mm]ath\S+-\S+$', char.fontname) is not None:
        return True
    return False

# transform pdfminer object hierarchy to a tree of objects suited to our purposes
def search_for_text(obj):
    if isinstance(obj, LTTextBox):
#         types = set(type(o) for o in obj._objs)
#         print(types)
        return {
            'type': 'box',
            'value': [search_for_text(o) for o in obj._objs]
        }
    elif isinstance(obj, LTTextLine):
        return {
            'type': 'line',
            'value': analyze_line(obj, is_exception)
        }
    elif isinstance(obj, (LTFigure, LTPage)):
        ret = []
        for o in obj._objs:
            text = search_for_text(o)
            if text is not None:
                ret.append(text)
        return ret
    else:
        pass
#         print('rare type', type(obj))

# Merge a sequence of chars into sequence of chunks with the same 
def analyze_line(obj, exception_f=None):
    # elements that pass exception_f(element) will be merged "greedily" into neighbouring chunks
    exception_f = exception_f or (lambda x: True)
    chars = deque(o for o in obj._objs if isinstance(o, LTChar) or isinstance(o, LTAnno))
    
    chunks = deque()
    
    while len(chars) > 0:
        # init chunk criteria
        size = None
        fontname = None
        init = False # whether there is a non-exception regular element in the chunk yet
        chunk = []
        
        while len(chars) > 0:
            c = chars[0]
            if exception_f(c):
                chunk.append(chars.popleft()._text)
                continue

            # first "regular" element
            if not init:
                init = True
                size = c.size
                fontname = c.fontname
                chunk.append(chars.popleft()._text)
                continue

            if (size is None or size == c.size) and (fontname is None or fontname == c.fontname):
                chunk.append(chars.popleft()._text)
            else:
                break
        
        # new chunk
        chunks.append({
            'type': 'chunk',
            'size': size,
            'fontname': fontname,
            'text': ''.join(chunk),
        })
    return tuple(chunks)
               

            
document=createPDFDoc(os.path.join(sample_pdf_dir, "2019.pdf"))
device,interpreter=createDeviceInterpreter()
pages=PDFPage.create_pages(document)

size_counter = Counter()

# print structure and get font size distribution
def print_structure(f, objs):
    for box in objs:
        if box is not None and len(box) > 0:
            assert box['type']=='box'
            for line in box['value']:
        #         print (line)
                assert line['type']=='line'
                for chunk in line['value']:
                    assert chunk['type']=='chunk'
    #                 _ = f.write('font: ' + (chunk['fontname'] if chunk['fontname'] is not None else 'NONE')+ ' ' + chunk['text'] + '\n')
                    _ = f.write(chunk['text'] + '\n')
                    size_counter[chunk['size']] += len(chunk['text'])
    

with open(os.path.join(output_dir, 'text.txt'), 'w') as f:

    for page in pages:
        interpreter.process_page(page)
        layout = device.get_result()
        print_structure(f, search_for_text(layout))
        
        layout = device.get_result()
        structure = search_for_text(layout)
        print_structure(f, structure)

# %% [markdown]
# ### Idea: find semantics behind char distribution (additional text / figure text etc. / main text / headings)
# - take the cluster including the most popular font size as the point of reference and take lower and higher font size clusters as more auxiliary and more summarizing
#
# agglomerative clustering:
#
#
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html#sklearn.cluster.AgglomerativeClustering
#
# #### pros
# - constraints on connectivity
# - seems to work nicely and create clusters of various sizes
#
# #### cons
# - not very fast
# - cannot be parallel
# - no sample weights (data can only be duplicated)

# %%
# first fontsize clustering experiments
from sklearn.cluster import KMeans

size_counts = sorted([item for item in size_counter.items() if item[0] is not None], key=lambda x:x[0])
x, y = zip(*size_counts)

kmeans = KMeans(n_clusters=3)
c = kmeans.fit_predict(np.reshape(x, (-1, 1)), sample_weight=y)
kmeans.cluster_centers_

colors = [matplotlib.cm.get_cmap('Set1').colors[label] for label in c] 
fig, ax = plt.subplots()
ax.set_yscale('log')
ax.xaxis.label.set_color('red')
ax.yaxis.label.set_color('red')
ax.tick_params(axis='x', colors='red')
ax.tick_params(axis='y', colors='red')
ax.set_xlabel('font size')
ax.set_ylabel('log character counts')
ax.bar(x, y, color=colors)
# Out:
# array([[ 5.83036027],
#        [21.9178    ],
#        [ 8.91731124]])
# Text(0.5, 0, 'font size')
# Text(0, 0.5, 'log character counts')
# <BarContainer object of 36 artists>

# %%
# count sizes for a set of pdfs
import os
from collections import Counter

def count_sizes(f, objs, counter):
    for obj in objs:
        if isinstance(obj, dict):
            assert obj['type']=='box'
            for line in obj['value']:
                assert line['type']=='line'
                for chunk in line['value']:
                    assert chunk['type']=='chunk'
                    counter[chunk['size']] += len(chunk['text'])

size_counters = []
for i, pdf in enumerate(sample_pdfs):
    print('{}/{} pdfs'.format(i+1, len(sample_pdfs)), end='\r')
    document=createPDFDoc(os.path.join(sample_pdf_dir, pdf))
    device,interpreter=createDeviceInterpreter()
    pages=PDFPage.create_pages(document)
    
    size_counter = Counter()
    for page in pages:
        interpreter.process_page(page)
        layout = device.get_result()
        structure = search_for_text(layout)
        count_sizes(f, structure, size_counter)
    size_counters.append(size_counter)
# Out:
# 37/37 pdfs

# %%
def plot_size_clusters(ax, vals, counts, labels, colors=None, title=''):
    ax.set_yscale('log')
    ax.xaxis.label.set_color('red')
    ax.yaxis.label.set_color('red')
    ax.tick_params(axis='x', colors='red')
    ax.tick_params(axis='y', colors='red')
    ax.set_xlabel('font size')
    ax.set_ylabel('log character counts')
    ax.set_title(title + ', all chars: ' + str(np.sum(y)))
    ax.set_xlim(2,35)
    ax.bar(vals, counts, color=colors, width=0.5, alpha=0.8)

# %%
# draw font size histograms for different pdfs
from sklearn.cluster import KMeans
from sklearn.neighbors import kneighbors_graph


n_clusters = 4

# first batch KMeans experiments...
def cluster_sizes_kmeans(vals, counts):
    avg = np.average(vals, weights=counts)
    logvals = np.log2(avg + (vals - avg)/np.std(vals - avg))
    kmeans = KMeans(n_clusters=n_clusters)
    labels = kmeans.fit_predict(np.reshape(logvals, (-1, 1)), sample_weight=counts)
    return kmeans, labels



fig, axes = plt.subplots(int(np.ceil(len(sample_pdfs)/2.)), 2, figsize=(20, 5*len(sample_pdfs)/2))
fig.tight_layout(pad=3.0)
for i, (size_counter, pdf, ax) in enumerate(zip(size_counters, sample_pdfs, axes.flatten())):
    print('{}/{} pdfs'.format(i+1, len(sample_pdfs)), end='\r')
    size_counts = sorted([item for item in size_counter.items() if item[0] is not None], key=lambda x:x[0])
    vals, counts = zip(*size_counts)
    kmeans, labels = cluster_sizes_kmeans(vals, counts)
    
    # ensure cluster integer labels raise in the direction of higher font size
    # so all graphs have the same order of colours
    center_indices = np.argsort(kmeans.cluster_centers_.flatten())
    order_fix_map = {center_indices[label]: label for label in range(n_clusters)}
    colors = [matplotlib.cm.get_cmap('Set1').colors[order_fix_map[label]] for label in labels] 
    plot_size_clusters(ax, vals, counts, labels, colors=colors, title=pdf)
# Out:
# 37/37 pdfs

# %%
# draw font size histograms for different pdfs
from sklearn.cluster import AgglomerativeClustering
from sklearn.neighbors import kneighbors_graph

def cluster_sizes_constrained(vals, counts):
    logvals = np.log2(vals)
    samples = np.reshape(logvals, (-1, 1))
    
    # docs:
    # https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html#sklearn.cluster.AgglomerativeClustering
    
    # no sample weights: duplicate samples to reflect somehow the counts 
    # (but not duplicate too much or it will slow down very badly)
    repeat = np.ceil(np.sqrt(counts)).astype(int)
    weighted = np.repeat(samples, repeat, axis=0)
    
    # constrain 1: extreme font size values must not be in the same clusters 
    # (every article has some headings and secondary information like margins / references / captions)
    connectivity = kneighbors_graph(weighted, int(np.round(weighted.shape[0] * 0.7)), include_self=True)
    
    # constrain 2: font sizes fulfilling more or less the same function will vary within a threshold
    # This threshold should be relative to the overall font size variability within an article
    # In some articles even the title is barely larger than the main text
    # In such cases minor differences in font size should allow for distinctions
    distance_threshold = np.std(vals)*0.1
    ac = AgglomerativeClustering(n_clusters=None, 
                                 linkage='average', 
                                 connectivity=connectivity,
                                 distance_threshold=distance_threshold
                                )
    # fit labels to the duplicated data
    skewed_labels = ac.fit_predict(weighted)
#     print(repeat, '\n', np.cumsum(repeat))

    # retrieve the labels for the original (non-duplicated data)
    labels = skewed_labels[np.cumsum(repeat) - repeat[0]]
    return ac, labels


fig, axes = plt.subplots(int(np.ceil(len(sample_pdfs)/2.)), 2, figsize=(20, 5*len(sample_pdfs)/2))
fig.tight_layout(pad=3.0)
for i, (size_counter, pdf, ax) in enumerate(zip(size_counters, sample_pdfs, axes.flatten())):
    print('{}/{} pages'.format(i+1, len(sample_pdfs)), end='\r')
    size_counts = sorted([item for item in size_counter.items() if item[0] is not None], key=lambda x:x[0])
    vals, counts = zip(*size_counts)
    ac, labels = cluster_sizes_constrained(vals, counts)
    
    # ensure cluster integer labels raise in the direction of higher font size
    # so all graphs have the same order of colours
    # (it might not be the simplest ways, but IT WORKS)
    label_names, indices = np.unique(labels, return_index=True)
    new_pos = label_names[np.argsort(indices)]
    order_fix_map = {p: i for i, p in enumerate(new_pos)}
    colors = [matplotlib.cm.get_cmap('Set1').colors[order_fix_map[label]] for label in labels] 
    
    plot_size_clusters(ax, vals, counts, labels, colors=colors, title=pdf)
# Out:
# 37/37 pages

# %%
# probably most pdf documents don't have outlines...

from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument

# Open a PDF document.
fp = open(os.path.join(sample_pdf_dir, '2019.pdf'), 'rb')
parser = PDFParser(fp)
document = PDFDocument(parser)

# Get the outlines of the document.
outlines = document.get_outlines()
for (level,title,dest,a,se) in outlines:
    print (level, title)
# Out:
# ---------------------------------------------------------------------------
# PDFNoOutlines                             Traceback (most recent call last)
# <ipython-input-19-7bc6b0c2666f> in <module>
#      10
#      11 # Get the outlines of the document.
# ---> 12 outlines = document.get_outlines()
#      13 for (level,title,dest,a,se) in outlines:
#      14     print (level, title)
#
# ~/Documents/materiały/kogni/Python/env/lib/python3.8/site-packages/pdfminer/pdfdocument.py in get_outlines(self)
#     700     def get_outlines(self):
#     701         if 'Outlines' not in self.catalog:
# --> 702             raise PDFNoOutlines
#     703
#     704         def search(entry, level):
#
# PDFNoOutlines:
